# %% [markdown]
# ## 1. Syntactic Patterns for Technical Terms ##

# %%
import nltk, re
from nltk.corpus import brown
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import regexp_tokenize
from nltk.util import ngrams
sent_tokenizer=nltk.data.load('tokenizers/punkt/english.pickle')

# %% [markdown]
# As seen in the Manning and Schuetze chapter, there is a well-known part-of-speech
# based pattern defined by Justeson and Katz for identifying simple noun phrases
# that often words well for pulling out keyphrases.
#
#  Technical Term  T = (A | N)+ (N | C)  | N
#
# Below, write a function to  define a chunker using the RegexpParser as illustrated in the NLTK book Chapter 7 section 2.3 *Chunking with Regular Expressions*.  You'll need to revise the grammar rules shown there to match the pattern shown above.  You can be liberal with your definition of what is meant by *N* here.  Also, C refers to cardinal number, which is CD in the brown corpus.

# %%
technical_term = r"""
            T:  {<JJ|NN.*>+ <NN.*|CD>|<NN.*>}
                {<N.*>+}"""

# %% [markdown]
# Below, write a function to call the chunker, run it on some sentences, and then print out the results for  those sentences.
#
# For uniformity, please run it on sentences 100 through 104 from the full tagged brown corpus.

# %%
def chunks(sent_list):
    brown_chunks = []
    cp = nltk.RegexpParser(technical_term)
    for sentence in sent_list:
        result = cp.parse(sentence)
        brown_chunks.append(result)
    return brown_chunks

chunks(nltk.corpus.brown.tagged_sents()[99:105])
# Out:
# [Tree('S', [(u'--', u'--'), Tree('T', [(u'Committee', u'NN'), (u'approval', u'NN')]), (u'of', u'IN'), Tree('T', [(u'Gov.', u'NN-TL')]), Tree('T', [(u'Price', u'NP'), (u"Daniel's", u'NP$')]), (u'``', u'``'), (u'abandoned', u'VBN'), Tree('T', [(u'property', u'NN')]), (u"''", u"''"), Tree('T', [(u'act', u'NN')]), (u'seemed', u'VBD'), (u'certain', u'JJ'), Tree('T', [(u'Thursday', u'NR')]), (u'despite', u'IN'), (u'the', u'AT'), Tree('T', [(u'adamant', u'JJ'), (u'protests', u'NNS')]), (u'of', u'IN'), Tree('T', [(u'Texas', u'NP')]), Tree('T', [(u'bankers', u'NNS')]), (u'.', u'.')]),
#  Tree('S', [Tree('T', [(u'Daniel', u'NP')]), (u'personally', u'RB'), (u'led', u'VBD'), (u'the', u'AT'), Tree('T', [(u'fight', u'NN')]), (u'for', u'IN'), (u'the', u'AT'), Tree('T', [(u'measure', u'NN')]), (u',', u','), (u'which', u'WDT'), (u'he', u'PPS'), (u'had', u'HVD'), (u'watered', u'VBN'), (u'down', u'RP'), (u'considerably', u'RB'), (u'since', u'IN'), (u'its', u'PP$'), Tree('T', [(u'rejection', u'NN')]), (u'by', u'IN'), (u'two', u'CD'), Tree('T', [(u'previous', u'JJ'), (u'Legislatures', u'NNS-TL')]), (u',', u','), (u'in', u'IN'), (u'a', u'AT'), Tree('T', [(u'public', u'JJ'), (u'hearing', u'NN')]), (u'before', u'IN'), (u'the', u'AT'), Tree('T', [(u'House', u'NN-TL'), (u'Committee', u'NN-TL')]), (u'on', u'IN-TL'), Tree('T', [(u'Revenue', u'NN-TL')]), (u'and', u'CC-TL'), Tree('T', [(u'Taxation', u'NN-TL')]), (u'.', u'.')]),
#  Tree('S', [(u'Under', u'IN'), Tree('T', [(u'committee', u'NN'), (u'rules', u'NNS')]), (u',', u','), (u'it', u'PPS'), (u'went', u'VBD'), (u'automatically', u'RB'), (u'to', u'IN'), (u'a', u'AT'), Tree('T', [(u'subcommittee', u'NN')]), (u'for', u'IN'), (u'one', u'CD'), Tree('T', [(u'week', u'NN')]), (u'.', u'.')]),
#  Tree('S', [(u'But', u'CC'), Tree('T', [(u'questions', u'NNS')]), (u'with', u'IN'), (u'which', u'WDT'), Tree('T', [(u'committee', u'NN'), (u'members', u'NNS')]), (u'taunted', u'VBD'), Tree('T', [(u'bankers', u'NNS')]), (u'appearing', u'VBG'), (u'as', u'CS'), Tree('T', [(u'witnesses', u'NNS')]), (u'left', u'VBD'), (u'little', u'AP'), Tree('T', [(u'doubt', u'NN')]), (u'that', u'CS'), (u'they', u'PPSS'), (u'will', u'MD'), (u'recommend', u'VB'), Tree('T', [(u'passage', u'NN')]), (u'of', u'IN'), (u'it', u'PPO'), (u'.', u'.')]),
#  Tree('S', [Tree('T', [(u'Daniel', u'NP')]), (u'termed', u'VBD'), (u'``', u'``'), (u'extremely', u'RB'), (u'conservative', u'JJ'), (u"''", u"''"), (u'his', u'PP$'), Tree('T', [(u'estimate', u'NN')]), (u'that', u'CS'), (u'it', u'PPS'), (u'would', u'MD'), (u'produce', u'VB'), (u'17', u'CD'), (u'million', u'CD'), Tree('T', [(u'dollars', u'NNS')]), (u'to', u'TO'), (u'help', u'VB'), (u'erase', u'VB'), (u'an', u'AT'), (u'anticipated', u'VBN'), Tree('T', [(u'deficit', u'NN')]), (u'of', u'IN'), (u'63', u'CD'), (u'million', u'CD'), Tree('T', [(u'dollars', u'NNS')]), (u'at', u'IN'), (u'the', u'AT'), Tree('T', [(u'end', u'NN')]), (u'of', u'IN'), (u'the', u'AT'), Tree('T', [(u'current', u'JJ'), (u'fiscal', u'JJ'), (u'year', u'NN')]), (u'next', u'AP'), Tree('T', [(u'Aug.', u'NP')]), (u'31', u'CD'), (u'.', u'.')]),
#  Tree('S', [(u'He', u'PPS'), (u'told', u'VBD'), (u'the', u'AT'), Tree('T', [(u'committee', u'NN')]), (u'the', u'AT'), Tree('T', [(u'measure', u'NN')]), (u'would', u'MD'), (u'merely', u'RB'), (u'provide', u'VB'), Tree('T', [(u'means', u'NNS')]), (u'of', u'IN'), (u'enforcing', u'VBG'), (u'the', u'AT'), Tree('T', [(u'escheat', u'NN'), (u'law', u'NN')]), (u'which', u'WDT'), (u'has', u'HVZ'), (u'been', u'BEN'), (u'on', u'IN'), (u'the', u'AT'), Tree('T', [(u'books', u'NNS')]), (u'``', u'``'), (u'since', u'IN'), Tree('T', [(u'Texas', u'NP')]), (u'was', u'BEDZ'), (u'a', u'AT'), Tree('T', [(u'republic', u'NN')]), (u"''", u"''"), (u'.', u'.')])]

# %% [markdown]
# Then extract out the phrases themselves on sentences 100 through 160 using the subtree extraction technique shown in the
# *Exploring Text Corpora* category.

# %%
print(nltk.corpus.brown.tagged_sents()[99:160])
# Out:
# [[(u'--', u'--'), (u'Committee', u'NN'), (u'approval', u'NN'), (u'of', u'IN'), (u'Gov.', u'NN-TL'), (u'Price', u'NP'), (u"Daniel's", u'NP$'), (u'``', u'``'), (u'abandoned', u'VBN'), (u'property', u'NN'), (u"''", u"''"), (u'act', u'NN'), (u'seemed', u'VBD'), (u'certain', u'JJ'), (u'Thursday', u'NR'), (u'despite', u'IN'), (u'the', u'AT'), (u'adamant', u'JJ'), (u'protests', u'NNS'), (u'of', u'IN'), (u'Texas', u'NP'), (u'bankers', u'NNS'), (u'.', u'.')], [(u'Daniel', u'NP'), (u'personally', u'RB'), (u'led', u'VBD'), (u'the', u'AT'), (u'fight', u'NN'), (u'for', u'IN'), (u'the', u'AT'), (u'measure', u'NN'), (u',', u','), (u'which', u'WDT'), (u'he', u'PPS'), (u'had', u'HVD'), (u'watered', u'VBN'), (u'down', u'RP'), (u'considerably', u'RB'), (u'since', u'IN'), (u'its', u'PP$'), (u'rejection', u'NN'), (u'by', u'IN'), (u'two', u'CD'), (u'previous', u'JJ'), (u'Legislatures', u'NNS-TL'), (u',', u','), (u'in', u'IN'), (u'a', u'AT'), (u'public', u'JJ'), (u'hearing', u'NN'), (u'before', u'IN'), (u'the', u'AT'), (u'House', u'NN-TL'), (u'Committee', u'NN-TL'), (u'on', u'IN-TL'), (u'Revenue', u'NN-TL'), (u'and', u'CC-TL'), (u'Taxation', u'NN-TL'), (u'.', u'.')], [(u'Under', u'IN'), (u'committee', u'NN'), (u'rules', u'NNS'), (u',', u','), (u'it', u'PPS'), (u'went', u'VBD'), (u'automatically', u'RB'), (u'to', u'IN'), (u'a', u'AT'), (u'subcommittee', u'NN'), (u'for', u'IN'), (u'one', u'CD'), (u'week', u'NN'), (u'.', u'.')], [(u'But', u'CC'), (u'questions', u'NNS'), (u'with', u'IN'), (u'which', u'WDT'), (u'committee', u'NN'), (u'members', u'NNS'), (u'taunted', u'VBD'), (u'bankers', u'NNS'), (u'appearing', u'VBG'), (u'as', u'CS'), (u'witnesses', u'NNS'), (u'left', u'VBD'), (u'little', u'AP'), (u'doubt', u'NN'), (u'that', u'CS'), (u'they', u'PPSS'), (u'will', u'MD'), (u'recommend', u'VB'), (u'passage', u'NN'), (u'of', u'IN'), (u'it', u'PPO'), (u'.', u'.')], [(u'Daniel', u'NP'), (u'termed', u'VBD'), (u'``', u'``'), (u'extremely', u'RB'), (u'conservative', u'JJ'), (u"''", u"''"), (u'his', u'PP$'), (u'estimate', u'NN'), (u'that', u'CS'), (u'it', u'PPS'), (u'would', u'MD'), (u'produce', u'VB'), (u'17', u'CD'), (u'million', u'CD'), (u'dollars', u'NNS'), (u'to', u'TO'), (u'help', u'VB'), (u'erase', u'VB'), (u'an', u'AT'), (u'anticipated', u'VBN'), (u'deficit', u'NN'), (u'of', u'IN'), (u'63', u'CD'), (u'million', u'CD'), (u'dollars', u'NNS'), (u'at', u'IN'), (u'the', u'AT'), (u'end', u'NN'), (u'of', u'IN'), (u'the', u'AT'), (u'current', u'JJ'), (u'fiscal', u'JJ'), (u'year', u'NN'), (u'next', u'AP'), (u'Aug.', u'NP'), (u'31', u'CD'), (u'.', u'.')], [(u'He', u'PPS'), (u'told', u'VBD'), (u'the', u'AT'), (u'committee', u'NN'), (u'the', u'AT'), (u'measure', u'NN'), (u'would', u'MD'), (u'merely', u'RB'), (u'provide', u'VB'), (u'means', u'NNS'), (u'of', u'IN'), (u'enforcing', u'VBG'), (u'the', u'AT'), (u'escheat', u'NN'), (u'law', u'NN'), (u'which', u'WDT'), (u'has', u'HVZ'), (u'been', u'BEN'), (u'on', u'IN'), (u'the', u'AT'), (u'books', u'NNS'), (u'``', u'``'), (u'since', u'IN'), (u'Texas', u'NP'), (u'was', u'BEDZ'), (u'a', u'AT'), (u'republic', u'NN'), (u"''", u"''"), (u'.', u'.')], [(u'It', u'PPS'), (u'permits', u'VBZ'), (u'the', u'AT'), (u'state', u'NN'), (u'to', u'TO'), (u'take', u'VB'), (u'over', u'RP'), (u'bank', u'NN'), (u'accounts', u'NNS'), (u',', u','), (u'stocks', u'NNS'), (u'and', u'CC'), (u'other', u'AP'), (u'personal', u'JJ'), (u'property', u'NN'), (u'of', u'IN'), (u'persons', u'NNS'), (u'missing', u'VBG'), (u'for', u'IN'), (u'seven', u'CD'), (u'years', u'NNS'), (u'or', u'CC'), (u'more', u'AP'), (u'.', u'.')], [(u'The', u'AT'), (u'bill', u'NN'), (u',', u','), (u'which', u'WDT'), (u'Daniel', u'NP'), (u'said', u'VBD'), (u'he', u'PPS'), (u'drafted', u'VBD'), (u'personally', u'RB'), (u',', u','), (u'would', u'MD'), (u'force', u'VB'), (u'banks', u'NNS'), (u',', u','), (u'insurance', u'NN'), (u'firms', u'NNS'), (u',', u','), (u'pipeline', u'NN'), (u'companies', u'NNS'), (u'and', u'CC'), (u'other', u'AP'), (u'corporations', u'NNS'), (u'to', u'TO'), (u'repo ...

# %%
brown_chunks = chunks(nltk.corpus.brown.tagged_sents()[100:161]) 
for tree in brown_chunks:
    for subtree in tree.subtrees():
        if subtree.label() == 'T':
            print(subtree)
# Out:
# (T Daniel/NP)
# (T fight/NN)
# (T measure/NN)
# (T rejection/NN)
# (T previous/JJ Legislatures/NNS-TL)
# (T public/JJ hearing/NN)
# (T House/NN-TL Committee/NN-TL)
# (T Revenue/NN-TL)
# (T Taxation/NN-TL)
# (T committee/NN rules/NNS)
# (T subcommittee/NN)
# (T week/NN)
# (T questions/NNS)
# (T committee/NN members/NNS)
# (T bankers/NNS)
# (T witnesses/NNS)
# (T doubt/NN)
# (T passage/NN)
# (T Daniel/NP)
# (T estimate/NN)
# (T dollars/NNS)
# (T deficit/NN)
# (T dollars/NNS)
# (T end/NN)
# (T current/JJ fiscal/JJ year/NN)
# (T Aug./NP)
# (T committee/NN)
# (T measure/NN)
# (T means/NNS)
# (T escheat/NN law/NN)
# (T books/NNS)
# (T Texas/NP)
# (T republic/NN)
# (T state/NN)
# (T bank/NN accounts/NNS)
# (T stocks/NNS)
# (T personal/JJ property/NN)
# (T persons/NNS)
# (T years/NNS)
# (T bill/NN)
# (T Daniel/NP)
# (T banks/NNS)
# (T insurance/NN firms/NNS)
# (T pipeline/NN companies/NNS)
# (T corporations/NNS)
# (T such/JJ property/NN)
# (T state/NN treasurer/NN)
# (T escheat/NN law/NN)
# (T such/JJ property/NN)
# (T Daniel/NP)
# (T Dewey/NP Lawrence/NP)
# (T Tyler/NP)
# (T lawyer/NN)
# (T Texas/NP-TL)
# (T Bankers/NNS-TL Association/NN-TL)
# (T opposition/NN keynote/NN)
# (T banks/NNS)
# (T contractual/JJ obligations/NNS)
# (T depositors/NNS)
# (T confidence/NN)
# (T bank/NN customers/NNS)
# (T confidence/NN)
# (T banks/NNS)
# (T economy/NN)
# (T circulation/NN)
# (T millions/NNS)
# (T dollars/NNS)
# (T Rep./NN-TL)
# (T Charles/NP E./NP Hughes/NP)
# (T Sherman/NP)
# (T sponsor/NN)
# (T bill/NN)
# (T failure/NN)
# (T gift/NN)
# (T taxpayers'/NNS$ pockets/NNS)
# (T banks/NNS)
# (T insurance/NN)
# (T pipeline/NN companies/NNS)
# (T contention/NN)
# (T bankers/NNS)
# (T Scott/NP Hudson/NP)
# (T Sherman/NP)
# (T Gaynor/NP B./NP Jones/NP)
# (T Houston/NP)
# (T J./NP B./NP Brady/NP)
# (T Harlingen/NP)
# (T Howard/NP Cox/NP)
# (T Austin/NP)
# (T Cox/NP)
# (T bill/NN)
# (T contracts/NNS)
# (T notice/NN)
# (T hearing/NN)
# (T bill/NN)
# (T Monday/NR)
# (T Austin/NP-HL)
# (T Texas/NP-HL)
# (T Senators/NNS)
# (T Thursday/NR)
# (T bill/NN)
# (T Sen./NN-TL)
# (T George/NP Parkhouse/NP)
# (T Dallas/NP)
# (T establishment/NN)
# (T day/NN schools/NNS)
# (T Dallas/NP)
# (T counties/NNS)
# (T bill/NN)
# (T special/JJ schooling/NN)
# (T deaf/JJ students/NNS)
# (T scholastic/JJ age/NN)
# (T cost/NN)
# (T state/NN)
# (T debate/NN)
# (T Senate/NN-TL)
# (T bill/NN)
# (T House/NN-TL)
# (T Texas/NP-TL)
# (T Education/NN-TL Agency/NN-TL)
# (T county-wide/JJ day/NN schools/NNS)
# (T counties/NNS)
# (T population/NN)
# (T deaf/JJ children/NNS)
# (T years/NNS)
# (T age/NN)
# (T day/NN schools/NNS)
# (T ones/NNS)
# (T Texas/NP-TL)
# (T School/NN-TL)
# (T budget/NN)
# (T day/NN schools/NNS)
# (T counties/NNS)
# (T Dallas/NP)
# (T Harris/NP)
# (T Bexar/NP)
# (T Tarrant/NP)
# (T El/NP Paso/NP)
# (T $451,500/NNS)
# (T savings/NNS)
# (T $157,460/NNS)
# (T year's/NN$ capital/NN outlay/NN)
# (T $88,000/NNS)
# (T Parkhouse/NP)
# (T Senate/NN-TL)
# (T TEA/NN)
# (T scholastics/NNS)
# (T day/NN school/NN)
# (T Dallas/NP-TL)
# (T County/NN-TL)
# (T Austin/NP)
# (T state/NN deaf/JJ school/NN)
# (T Dallas/NP)
# (T debate/NN)
# (T horse/NN race/NN parimutuels/NNS)
# (T Reps./NNS-TL)
# (T V./NP E./NP)
# (T Red/NP)
# (T Berry/NP)
# (T Joe/NP Ratcliff/NP)
# (T details/NNS)
# (T Ratcliff/NP)
# (T home/NR)
# (T folks/NNS)
# (T Dallas/NP)
# (T Berry's/NP$)
# (T constitutional/JJ amendment/NN)
# (T letters/NNS)
# (T horse/NN race/NN betting/NN)
# (T Ratcliff/NP)
# (T people/NNS)
# (T question/NN)
# (T political/JJ career/NN)
# (T Rep./NN-TL)
# (T Berry/NP)
# (T ex-gambler/NN)
# (T San/NP Antonio/NP)
# (T advocacy/NN)
# (T ponies/NNS)
# (T House/NN-TL committee/NN)
# (T local/JJ option/NN proposal/NN)
# (T favorable/JJ report/NN)
# (T resolution/NN)
# (T hard/JJ sledding/NN)
# (T house/NN)
# (T Senate/NN-TL)
# (T bill/NN)
# (T State/NN-TL Health/NN-TL Department's/NN$-TL authority/NN)
# (T assistance/NN)
# (T cities/NNS)
# (T senate/NN)
# (T meager/JJ fare/NN)
# (T House/NN-TL bills/NNS)
# (T committees/NNS)
# (T calendar/NN)
# (T acts/NNS)
# (T school/NN districts/NNS)
# (T authority/NN)
# (T Beaumont/NP-TL)
# (T Navigation/NN-TL District/NN-TL)
# (T act/NN)
# (T creation/NN)
# (T Lamar/NP-TL)
# (T county/NN-TL Hospital/NN-TL District/NN-TL)
# (T special/JJ constitutional/JJ amendment/NN)
# (T dissent/NN)
# (T senators/NNS)
# (T bill/NN)
# (T Sen./NN-TL)
# (T A./NP R./NP Schwartz/NP)
# (T Galveston/NP)
# (T establishment/NN)
# (T future/NN)
# (T school/NN)
# (T Gulf/NN-TL Coast/NN-TL district/NN)
# (T Money/NN)
# (T construction/NN)
# (T meantime/NN)
# (T State/NN-TL Hospital/NN-TL board/NN)
# (T gifts/NNS)
# (T donations/NNS)
# (T site/NN)
# (T tax/NN revision/NN bills/NNS)
# (T Sen./NN-TL)
# (T Louis/NP Crump/NP)
# (T San/NP Saba/NP)
# (T retailers/NNS)
# (T group/NN)
# (T miscellaneous/JJ excise/NN taxes/NNS)
# (T requirement/NN)
# (T return/NN)
# (T retailers/NNS)
# (T certificate/NN)
# (T correctness/NN)
# (T violation/NN)
# (T penalty/NN)
# (T years/NNS)
# (T prison/NN)
# (T $1,000/NNS fine/NN)
# (T series/NN)
# (T recommendations/NNS)
# (T Texas/NP-TL)
# (T Research/NN-TL League/NN-TL)
# (T bill/NN)
# (T Sen./NN-TL)
# (T A./NP M./NP Aikin/NP Jr./NP)
# (T Paris/NP)
# (T real/JJ estate/NN brokers/NNS)
# (T fee/NN)
# (T $12/NNS annual/JJ occupation/NN license/NN)
# (T brokers/NNS)
# (T stocks/NNS)
# (T bonds/NNS)
# (T Natural/JJ gas/NN public/JJ utility/NN companies/NNS)
# (T right/NN)
# (T eminent/JJ domain/NN)
# (T bill/NN)
# (T Sen./NN-TL)
# (T Frank/NP Owen/NP)
# (T El/NP Paso/NP)
# (T sites/NNS)
# (T underground/JJ storage/NN reservoirs/NNS)
# (T gas/NN)
# (T Marshall/NP Formby/NP)
# (T Plainview/NP)
# (T chairman/NN)
# (T Texas/NP-TL)
# (T Highway/NN-TL Commission/NN-TL)
# (T plan/NN)
# (T appointment/NN future/JJ vacancies/NNS)
# (T Legislature/NN-TL)
# (T Congress/NP)
# (T need/NN)
# (T costly/JJ special/JJ elections/NNS)
# (T Formby's/NP$)
# (T plan/NN)
# (T appointee/NN)
# (T board/NN)
# (T governor/NN)
# (T lieutenant/NN governor/NN)
# (T speaker/NN)
# (T House/NN-TL)
# (T attorney/NN general/NN)
# (T justice/NN)
# (T Texas/NP-TL)
# (T Court/NN-TL)
# (T Austin/NP-HL)
# (T Texas/NP-HL)
# (T State/NN representatives/NNS)
# (T Thursday/NR)
# (T poll/NN)
# (T kind/NN)
# (T taxes/NNS)
# (T Texans/NPS)
# (T adverse/JJ vote/NN)
# (T State/NN-TL Affairs/NNS-TL Committee/NN-TL)
# (T bill/NN)
# (T referendum/NN)
# (T April/NP)
# (T ballot/NN)
# (T Texas/NP)
# (T U.S./NP)
# (T senator/NN)
# (T Rep./NN-TL)
# (T Wesley/NP Roberts/NP)
# (T Seminole/NP)
# (T sponsor/NN)
# (T poll/NN idea/NN)
# (T delay/NN)
# (T committee/NN)
# (T bill/NN)
# (T Texan/NP-TL)
# (T Chairman/NN-TL)
# (T Bill/NP Hollowell/NP)
# (T committee/NN)
# (T public/JJ hearing/NN)
# (T Feb./NP)
# (T proposal/NN)
# (T final/JJ legislative/JJ approval/NN)
# (T two-thirds/NNS majorities/NNS)
# (T March/NP)
# (T April/NP)
# (T ballot/NN)
# (T Roberts/NP)
# (T Opponents/NNS)
# (T ballot/NN)
# (T information/NN)
# (T tax/NN proposals/NNS)
# (T voters/NNS)
# (T intelligent/JJ choice/NN)
# (T Dallas/NP)
# (T members/NNS)
# (T Roberts/NP)
# (T Rep./NN-TL)
# (T Bill/NP Jones/NP)
# (T Austin/NP-HL)
# (T Texas/NP-HL)
# (T Paradise/NN-TL)
# (T water/NN needs/NNS)
# (T Texas'/NP$)
# (T big/JJ cities/NNS)
# (T Thursday/NR)
# (T Rep./NN-TL)
# (T James/NP Cotten/NP)
# (T Weatherford/NP)
# (T water/NN development/NN bill/NN)
# (T Texas/NP-TL)
# (T House/NN-TL)
# (T Representatives/NNS-TL)
# (T effort/NN)
# (T big/JJ cities/NNS)
# (T Dallas/NP)
# (T Fort/NN-TL)
# (T Worth/NP)
# (T places/NNS)
# (T Paradise/NN-TL)
# (T Wise/NP-TL)
# (T County/NN-TL hamlet/NN)
# (T people/NNS)
# (T shouting/NN)
# (T bill/NN)
# (T Senate/NN-TL)
# (T similar/JJ proposal/NN)
# (T Sen./NN-TL)
# (T George/NP Parkhouse/NP)
# (T Dallas/NP)
# (T fire/NN)
# (T Cotten/NP)
# (T Dallas/NP)
# (T Sen./NN-TL)
# (T Parkhouse/NP)
# (T bill/NN)
# (T $5,000,000/NNS)
# (T $15,000,000/NNS)
# (T maximum/JJ loan/NN)
# (T state/NN)
# (T local/JJ water/NN project/NN)
# (T Cotten/NP)
# (T effort/NN)
# (T Parkhouse/NP)
# (T Dallas/NP)
# (T large/JJ cities/NNS)
# (T money/NN)
# (T Cotten/NP)
# (T water/NN)
# (T Texas/NP)
# (T Statements/NNS)
# (T legislators/NNS)
# (T Dallas/NP)
# (T water/NN program/NN)
# (T local/JJ bonds/NNS)
# (T populous/JJ places/NNS)
# (T pending/JJ bill/NN)
# (T Cotten's/NP$)
# (T attack/NN)
# (T bill's/NN$ defenders/NNS)
# (T small-town/NN legislators/NNS)
# (T J./NP W./NP Buchanan/NP)
# (T Dumas/NP)
# (T Eligio/NP)
# (T Kika/NP)
# (T De/NP La/NP Garza/NP)
# (T Mission/NN-TL)
# (T Sam/NP F./NP Collins/NP)
# (T Newton/NP)
# (T Joe/NP Chapman/NP)
# (T Sulphur/NN-TL Springs/NNS-TL)

# %% [markdown]
# ## 2. Identify Proper Nouns ##
# For this next task, write a new version of the chunker, but this time change it in two ways:
#  1. Make it recognize proper nouns
#  2. Make it work on your personal text collection which means that you need to run a tagger over your personal text collection.
#
# Note that the second requirements means that you need to run a tagger over your personal text collection before you design the proper noun recognizer.  You can use a pre-trained tagger or train your own on one of the existing tagged collections (brown, conll, or treebank)

# %% [markdown]
# **Tagger:** Your code for optionally training tagger, and for definitely running tagger on your personal collection goes here:

# %%
def create_data_sets(sentences):
    size = int(len(sentences) * 0.9)
    train_sents = sentences[:size]
    test_sents = sentences[size:]
    return train_sents, test_sents

def build_backoff_tagger (train_sents):
    t0 = nltk.DefaultTagger('NN')
    t1 = nltk.UnigramTagger(train_sents, backoff=t0)
    t2 = nltk.BigramTagger(train_sents, backoff=t1)
    t3 = nltk.TrigramTagger(train_sents, backoff=t2)
    return t3


def train_tagger(already_tagged_sents):
    train_sents, test_sents = create_data_sets(already_tagged_sents)
    ngram_tagger = build_backoff_tagger(train_sents)
    print ("%0.3f pos accuracy on test set" % ngram_tagger.evaluate(test_sents))
    return ngram_tagger

# %%
def tokenize_text(corpus):
    sent_tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
    raw_sents = sent_tokenizer.tokenize(corpus) # Split text into sentences    
    return [nltk.word_tokenize(word) for word in raw_sents]

# %%
def train_tagger_on_brown():
    modified_speech_sents = [[('common', 'JJ'), ('Hard-working', 'JJ'), ('people', 'NNS'), ('.', '.')],
                        [("I'm", 'PPSS+BEM'), ('a', 'AT'), ('Republican', 'NP'), ('.', '.')],
                        [("I'm", 'PPSS+BEM'), ('Republican', 'NP'),('.', '.')], 
                        [('the', 'AT'), ('Republican', 'NP'), ('politicians', 'NNS'), ('.', '.')],
                        [('the', 'AT'), ('American', 'NP'), ('people', 'NNS'), ('.', '.')]]


    brown_tagged_sents = brown.tagged_sents(categories=['adventure', 'editorial', 'fiction', 'government', 'hobbies',
    'humor', 'learned', 'lore', 'mystery', 'religion', 'reviews', 'romance'])
    
    #append hand-tagged cooking sentences to the front of the training data
    all_tagged_sents = modified_speech_sents + brown_tagged_sents
    return train_tagger(all_tagged_sents)

# %%
brown_tagger = train_tagger_on_brown()
# Out:
# 0.909 pos accuracy on test set

# %%
def tagme(sents, tagger):
    return [tagger.tag(sent) for sent in sents]

# %%
with open("speeches.txt") as w:
    text = w.read()

# %%
text = text.replace('\ufeff', '')
new_text = re.sub('[\n]+','\n', text)
sent_text = tokenize_text(new_text)

# %%
sent_text[0]
# Out:
# ['SPEECH', '1', '...', 'Thank', 'you', 'so', 'much', '.']

# %%
tagged_sents = tagme(sent_text,brown_tagger)

# %% [markdown]
# **Chunker:** Code for the proper noun chunker goes here:

# %%
grammar = "NC: {<NP.*>+}"

# %%
def my_chunker(sent_list):
    mychunks = []
    cp = nltk.RegexpParser(grammar)
    for sentence in sent_list:
        result = cp.parse(sentence)
        mychunks.append(result)
    return mychunks

# %% [markdown]
# **Test the Chunker:** Test your proper noun recognizer on a lot of sentences to see how well it is working.  You might want to add prepositions in order to improve your results.

# %%
chunks(nltk.corpus.brown.tagged_sents()[105:125])
# Out:
# [Tree('S', [('It', 'PPS'), ('permits', 'VBZ'), ('the', 'AT'), Tree('T', [('state', 'NN')]), ('to', 'TO'), ('take', 'VB'), ('over', 'RP'), Tree('T', [('bank', 'NN'), ('accounts', 'NNS')]), (',', ','), Tree('T', [('stocks', 'NNS')]), ('and', 'CC'), ('other', 'AP'), Tree('T', [('personal', 'JJ'), ('property', 'NN')]), ('of', 'IN'), Tree('T', [('persons', 'NNS')]), ('missing', 'VBG'), ('for', 'IN'), ('seven', 'CD'), Tree('T', [('years', 'NNS')]), ('or', 'CC'), ('more', 'AP'), ('.', '.')]),
#  Tree('S', [('The', 'AT'), Tree('T', [('bill', 'NN')]), (',', ','), ('which', 'WDT'), Tree('T', [('Daniel', 'NP')]), ('said', 'VBD'), ('he', 'PPS'), ('drafted', 'VBD'), ('personally', 'RB'), (',', ','), ('would', 'MD'), ('force', 'VB'), Tree('T', [('banks', 'NNS')]), (',', ','), Tree('T', [('insurance', 'NN'), ('firms', 'NNS')]), (',', ','), Tree('T', [('pipeline', 'NN'), ('companies', 'NNS')]), ('and', 'CC'), ('other', 'AP'), Tree('T', [('corporations', 'NNS')]), ('to', 'TO'), ('report', 'VB'), Tree('T', [('such', 'JJ'), ('property', 'NN')]), ('to', 'IN'), ('the', 'AT'), Tree('T', [('state', 'NN'), ('treasurer', 'NN')]), ('.', '.')]),
#  Tree('S', [('The', 'AT'), Tree('T', [('escheat', 'NN'), ('law', 'NN')]), ('cannot', 'MD*'), ('be', 'BE'), ('enforced', 'VBN'), ('now', 'RB'), ('because', 'CS'), ('it', 'PPS'), ('is', 'BEZ'), ('almost', 'RB'), ('impossible', 'JJ'), ('to', 'TO'), ('locate', 'VB'), Tree('T', [('such', 'JJ'), ('property', 'NN')]), (',', ','), Tree('T', [('Daniel', 'NP')]), ('declared', 'VBD'), ('.', '.')]),
#  Tree('S', [Tree('T', [('Dewey', 'NP'), ('Lawrence', 'NP')]), (',', ','), ('a', 'AT'), Tree('T', [('Tyler', 'NP')]), Tree('T', [('lawyer', 'NN')]), ('representing', 'VBG'), ('the', 'AT'), Tree('T', [('Texas', 'NP-TL')]), Tree('T', [('Bankers', 'NNS-TL'), ('Association', 'NN-TL')]), (',', ','), ('sounded', 'VBD'), ('the', 'AT'), Tree('T', [('opposition', 'NN'), ('keynote', 'NN')]), ('when', 'WRB'), ('he', 'PPS'), ('said', 'VBD'), ('it', 'PPS'), ('would', 'MD'), ('force', 'VB'), Tree('T', [('banks', 'NNS')]), ('to', 'TO'), ('violate', 'VB'), ('their', 'PP$'), Tree('T', [('contractual', 'JJ'), ('obligations', 'NNS')]), ('with', 'IN'), Tree('T', [('depositors', 'NNS')]), ('and', 'CC'), ('undermine', 'VB'), ('the', 'AT'), Tree('T', [('confidence', 'NN')]), ('of', 'IN'), Tree('T', [('bank', 'NN'), ('customers', 'NNS')]), ('.', '.')]),
#  Tree('S', [('``', '``'), ('If', 'CS'), ('you', 'PPSS'), ('destroy', 'VB'), Tree('T', [('confidence', 'NN')]), ('in', 'IN'), Tree('T', [('banks', 'NNS')]), (',', ','), ('you', 'PPSS'), ('do', 'DO'), ('something', 'PN'), ('to', 'IN'), ('the', 'AT'), Tree('T', [('economy', 'NN')]), ("''", "''"), (',', ','), ('he', 'PPS'), ('said', 'VBD'), ('.', '.')]),
#  Tree('S', [('``', '``'), ('You', 'PPSS'), ('take', 'VB'), ('out', 'RP'), ('of', 'IN'), Tree('T', [('circulation', 'NN')]), ('many', 'AP'), Tree('T', [('millions', 'NNS')]), ('of', 'IN'), Tree('T', [('dollars', 'NNS')]), ("''", "''"), ('.', '.')]),
#  Tree('S', [Tree('T', [('Rep.', 'NN-TL')]), Tree('T', [('Charles', 'NP'), ('E.', 'NP'), ('Hughes', 'NP')]), ('of', 'IN'), Tree('T', [('Sherman', 'NP')]), (',', ','), Tree('T', [('sponsor', 'NN')]), ('of', 'IN'), ('the', 'AT'), Tree('T', [('bill', 'NN')]), (',', ','), ('said', 'VBD'), ('a', 'AT'), Tree('T', [('failure', 'NN')]), ('to', 'TO'), ('enact', 'VB'), ('it', 'PPS'), ('would', 'MD'), ('amount', 'VB'), ('``', '``'), ('to', 'IN'), ('making', 'VBG'), ('a', 'AT'), Tree('T', [('gift', 'NN')]), ('out', 'RP'), ('of', 'IN'), ('the', 'AT'), Tree('T', [("taxpayers'", 'NNS$'), ('pockets', 'NNS')]), ('to', 'IN'), Tree('T', [('banks', 'NNS')]), (',', ','), Tree('T', [('insurance', 'NN')]), ('and', 'CC'), Tree('T', [('pipeline', 'NN'), ('companies', 'NNS')]), ("''", "''"), ('.', '.')]),
#  Tree('S', [('His', 'PP$'), Tree('T', [('contention', 'NN')]), ('was', 'BEDZ'), ('denied', 'VBN'), ('by', 'IN'), ('several', 'AP'), Tree('T', [('bankers', 'NNS')]), (',', ','), ('including', 'IN'), Tree('T', [('Scott', 'NP'), ('Hudson', 'NP')]), ('of', 'IN'), Tree('T', [('Sherman', 'NP')]), (',', ','), Tree('T', [('Gaynor', 'NP'), ('B.', 'NP'), ('Jones', 'NP')]), ('of', 'IN'), Tree('T', [('Houston', 'NP')]), (',', ','), Tree('T', [('J.', 'NP'), ('B.', 'NP'), ('Brady', 'NP')]), ('of', 'IN'), Tree('T', [('Harlingen', 'NP')]), ('and', 'CC'), Tree('T', [('Howard', 'NP'), ('Cox', 'NP')]), ('of', 'IN'), Tree('T', [('Austin', 'NP')]), ('.', '.')]),
#  Tree('S', [Tree('T', [('Cox', 'NP')]), ('argued', 'VBD'), ('that', 'CS'), ('the', 'AT'), Tree('T', [('bill', 'NN')]), ('is', 'BEZ'), ('``', '``'), ('probably', 'RB'), ('unconstitutional', 'JJ'), ("''", "''"), ('since', 'CS'), (',', ','), ('he', 'PPS'), ('said', 'VBD'), (',', ','), ('it', 'PPS'), ('would', 'MD'), ('impair', 'VB'), Tree('T', [('contracts', 'NNS')]), ('.', '.')]),
#  Tree('S', [('He', 'PPS'), ('also', 'RB'), ('complained', 'VBD'), ('that', 'CS'), ('not', '*'), ('enough', 'AP'), Tree('T', [('notice', 'NN')]), ('was', 'BEDZ'), ('given', 'VBN'), ('on', 'IN'), ('the', 'AT'), Tree('T', [('hearing', 'NN')]), (',', ','), ('since', 'CS'), ('the', 'AT'), Tree('T', [('bill', 'NN')]), ('was', 'BEDZ'), ('introduced', 'VBN'), ('only', 'RB'), ('last', 'AP'), Tree('T', [('Monday', 'NR')]), ('.', '.')]),
#  Tree('S', [Tree('T', [('Austin', 'NP-HL')]), (',', ',-HL'), Tree('T', [('Texas', 'NP-HL')])]),
#  Tree('S', [('--', '--'), Tree('T', [('Senators', 'NNS')]), ('unanimously', 'RB'), ('approved', 'VBD'), Tree('T', [('Thursday', 'NR')]), ('the', 'AT'), Tree('T', [('bill', 'NN')]), ('of', 'IN'), Tree('T', [('Sen.', 'NN-TL')]), Tree('T', [('George', 'NP'), ('Parkhouse', 'NP')]), ('of', 'IN'), Tree('T', [('Dallas', 'NP')]), ('authorizing', 'VBG'), Tree('T', [('establishment', 'NN')]), ('of', 'IN'), Tree('T', [('day', 'NN'), ('schools', 'NNS')]), ('for', 'IN'), ('the', 'AT'), ('deaf', 'JJ'), ('in', 'IN'), Tree('T', [('Dallas', 'NP')]), ('and', 'CC'), ('the', 'AT'), ('four', 'CD'), ('other', 'AP'), ('largest', 'JJT'), Tree('T', [('counties', 'NNS')]), ('.', '.')]),
#  Tree('S', [('The', 'AT'), Tree('T', [('bill', 'NN')]), ('is', 'BEZ'), ('designed', 'VBN'), ('to', 'TO'), ('provide', 'VB'), Tree('T', [('special', 'JJ'), ('schooling', 'NN')]), ('for', 'IN'), ('more', 'AP'), Tree('T', [('deaf', 'JJ'), ('students', 'NNS')]), ('in', 'IN'), ('the', 'AT'), Tree('T', [('scholastic', 'JJ'), ('age', 'NN')]), ('at', 'IN'), ('a', 'AT'), ('reduced', 'VBN'), Tree('T', [('cost', 'NN')]), ('to', 'IN'), ('the', 'AT'), Tree('T', [('state', 'NN')]), ('.', '.')]),
#  Tree('S', [('There', 'EX'), ('was', 'BEDZ'), ('no', 'AT'), Tree('T', [('debate', 'NN')]), ('as', 'CS'), ('the', 'AT'), Tree('T', [('Senate', 'NN-TL')]), ('passed', 'VBD'), ('the', 'AT'), Tree('T', [('bill', 'NN')]), ('on', 'IN'), ('to', 'IN'), ('the', 'AT'), Tree('T', [('House', 'NN-TL')]), ('.', '.')]),
#  Tree('S', [('It', 'PPS'), ('would', 'MD'), ('authorize', 'VB'), ('the', 'AT'), Tree('T', [('Texas', 'NP-TL')]), Tree('T', [('Education', 'NN-TL'), ('Agency', 'NN-TL')]), ('to', 'TO'), ('establish', 'VB'), Tree('T', [('county-wide', 'JJ'), ('day', 'NN'), ('schools', 'NNS')]), ('for', 'IN'), ('the', 'AT'), ('deaf', 'JJ'), ('in', 'IN'), Tree('T', [('counties', 'NNS')]), ('of', 'IN'), ('300,000', 'CD'), ('or', 'CC'), ('more', 'AP'), Tree('T', [('population', 'NN')]), (',', ','), ('require', 'VB'), Tree('T', [('deaf', 'JJ'), ('children', 'NNS')]), ('between', 'IN'), ('6', 'CD'), ('and', 'CC'), ('13', 'CD'), Tree('T', [('years', 'NNS')]), ('of', 'IN'), Tree('T', [('age', 'NN')]), ('to', 'TO'), ('attend', 'VB'), ('the', 'AT'), Tree('T', [('day', 'NN'), ('schools', 'NNS')]), (',', ','), ('permitting', 'VBG'), ('older', 'JJR'), Tree('T', [('ones', 'NNS')]), ('to', 'TO'), ('attend', 'VB'), ('the', 'AT'), ('residential', 'JJ'), Tree('T', [('Texas', 'NP-TL')]), Tree('T', [('School', 'NN-TL')]), ('for', 'IN-TL'), ('the', 'AT-TL'), ('Deaf', 'JJ-TL'), ('here', 'RB'), ('.', '.')]),
#  Tree('S', [('Operating', 'VBG'), Tree('T', [('budget', 'NN')]), ('for', 'IN'), ('the', 'AT'), Tree('T', [('day', 'NN'), ('schools', 'NNS')]), ('in', 'IN'), ('the', 'AT'), ('five', 'CD'), Tree('T', [('counties', 'NNS')]), ('of', 'IN'), Tree('T', [('Dallas', 'NP')]), (',', ','), Tree('T', [('Harris', 'NP')]), (',', ','), Tree('T', [('Bexar', 'NP')]), (',', ','), Tree('T', [('Tarrant', 'NP')]), ('and', 'CC'), Tree('T', [('El', 'NP'), ('Paso', 'NP')]), ('would', 'MD'), ('be', 'BE'), Tree('T', [('$451,500', 'NNS')]), (',', ','), ('which', 'WDT'), ('would', 'MD'), ('be', 'BE'), ('a', 'AT'), Tree('T', [('savings', 'NNS')]), ('of', 'IN'), Tree('T', [('$157,460', 'NNS')]), ('yearly', 'RB'), ('after', 'IN'), ('the', 'AT'), ('first', 'OD'), Tree('T', [("year's", 'NN$'), ('capital', 'NN'), ('outlay', 'NN')]), ('of', 'IN'), Tree('T', [('$88,000', 'NNS')]), ('was', 'BEDZ'), ('absorbed', 'VBN'), (',', ','), Tree('T', [('Parkhouse', 'NP')]), ('told', 'VBD'), ('the', 'AT'), Tree('T', [('Senate', 'NN-TL')]), ('.', '.')]),
#  Tree('S', [('The', 'AT'), Tree('T', [('TEA', 'NN')]), ('estimated', 'VBD'), ('there', 'EX'), ('would', 'MD'), ('be', 'BE'), ('182', 'CD'), Tree('T', [('scholastics', 'NNS')]), ('to', 'TO'), ('attend', 'VB'), ('the', 'AT'), Tree('T', [('day', 'NN'), ('school', 'NN')]), ('in', 'IN'), Tree('T', [('Dallas', 'NP-TL')]), Tree('T', [('County', 'NN-TL')]), (',', ','), ('saving', 'VBG'), ('them', 'PPO'), ('from', 'IN'), ('coming', 'VBG'), ('to', 'IN'), Tree('T', [('Austin', 'NP')]), ('to', 'TO'), ('live', 'VB'), ('in', 'IN'), ('the', 'AT'), Tree('T', [('state', 'NN'), ('deaf', 'JJ'), ('school', 'NN')]), ('.', '.')]),
#  Tree('S', [Tree('T', [('Dallas', 'NP')]), ('may', 'MD'), ('get', 'VB'), ('to', 'TO'), ('hear', 'VB'), ('a', 'AT'), Tree('T', [('debate', 'NN')]), ('on', 'IN'), Tree('T', [('horse', 'NN'), ('race', 'NN'), ('parimutuels', 'NNS')]), ('soon', 'RB'), ('between', 'IN'), Tree('T', [('Reps.', 'NNS-TL')]), Tree('T', [('V.', 'NP'), ('E.', 'NP')]), ('(', '('), Tree('T', [('Red', 'NP')]), (')', ')'), Tree('T', [('Berry', 'NP')]), ('and', 'CC'), Tree('T', [('Joe', 'NP'), ('Ratcliff', 'NP')]), ('.', '.')]),
#  Tree('S', [('While', 'CS'), Tree('T', [('details', 'NNS')]), ('are', 'BER'), ('still', 'RB'), ('to', 'TO'), ('be', 'BE'), ('worked', 'VBN'), ('out', 'RP'), (',', ','), Tree('T', [('Ratcliff', 'NP')]), ('said', 'VBD'), ('he', 'PPS'), ('expects', 'VBZ'), ('to', 'TO'), ('tell', 'VB'), Tree('T', [('home', 'NR')]), Tree('T', [('folks', 'NNS')]), ('in', 'IN'), Tree('T', [('Dallas', 'NP')]), ('why', 'WRB'), ('he', 'PPS'), ('thinks', 'VBZ'), Tree('T', [("Berry's", 'NP$')]), ('proposed', 'VBN'), Tree('T', [('constitutional', 'JJ'), ('amendment', 'NN')]), ('should', 'MD'), ('be', 'BE'), ('rejected', 'VBN'), ('.', '.')]),
#  Tree('S', [('``', '``'), ("We're", 'PPSS+BER'), ('getting', 'VBG'), ('more', 'AP'), ("'", "'"), ('pro', 'JJ'), ("'", "'"), Tree('T', [('letters', 'NNS')]), ('than', 'IN'), ("'", "'"), ('con', 'JJ'), ("'", "'"), ('on', 'IN'), Tree('T', [('horse', 'NN'), ('race', 'NN'), ('betting', 'NN')]), ("''", "''"), (',', ','), ('said', 'VBD'), Tree('T', [('Ratcliff', 'NP')]), ('.', '.')])]

# %% [markdown]
# **FreqDist Results:** After you have your proper noun recognizer working to your satisfaction, below  run it over your entire collection, feed the results into a FreqDist, and then print out the top 20 proper nouns by frequency.  That code goes here, along with the output:

# %%
mychunks = my_chunker(tagged_sents)
for tree in mychunks:
    for subtree in tree.subtrees():
        if subtree.label() == 'NC': 
            print(subtree)
# Out:
# (NC Steve/NP)
# (NC David/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Washington/NP)
# (NC Republican/NP)
# (NC Republican/NP)
# (NC Republicans/NPS)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Mexico/NP-TL)
# (NC China/NP)
# (NC Iraq/NP)
# (NC Donald/NP)
# (NC Iran/NP)
# (NC York/NP-TL)
# (NC Republican/NP)
# (NC Ryan/NP)
# (NC Democrats/NPS)
# (NC Iran/NP)
# (NC Syria/NP)
# (NC Syria/NP)
# (NC Syria/NP)
# (NC Midwest/NP)
# (NC China/NP)
# (NC Ohio/NP)
# (NC Saudi/NP Arabia/NP)
# (NC China/NP)
# (NC George/NP Washington/NP)
# (NC LaGuardia/NP)
# (NC Mr./NP)
# (NC Kennedy/NP)
# (NC Chinese/NPS)
# (NC Korea/NP-TL)
# (NC Korea/NP-TL)
# (NC China/NP)
# (NC Korea/NP-TL)
# (NC Korea/NP-TL)
# (NC Massachusetts/NP)
# (NC Bush/NP)
# (NC Bush/NP)
# (NC Bush/NP)
# (NC Abraham/NP Lincoln/NP)
# (NC Roberts/NP)
# (NC Jeb/NP)
# (NC Roberts/NP)
# (NC Roberts/NP)
# (NC Jeb/NP Bush/NP)
# (NC Iran/NP)
# (NC America/NP-TL)
# (NC Pennsylvania/NP)
# (NC Congress/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Nazis/NPS)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Mr./NP)
# (NC Iraq/NP)
# (NC Egypt/NP)
# (NC Syria/NP)
# (NC Americans/NPS)
# (NC Iran/NP)
# (NC NATO/NP-TL)
# (NC America/NP)
# (NC Europe/NP)
# (NC Asia/NP)
# (NC U.S./NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Poland/NP)
# (NC Egypt/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Israel/NP)
# (NC Cuba/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Copenhagen/NP)
# (NC Denmark/NP)
# (NC Olympics/NPS)
# (NC Korea/NP-TL)
# (NC China/NP)
# (NC China/NP)
# (NC Korea/NP-TL)
# (NC China/NP)
# (NC Korea/NP-TL)
# (NC China/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Christians/NPS)
# (NC Christians/NPS)
# (NC Iraq/NP)
# (NC Syria/NP)
# (NC Islam/NP)
# (NC Hillary/NP)
# (NC Islam/NP)
# (NC Americans/NPS)
# (NC Hillary/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Islam/NP)
# (NC Islam/NP)
# (NC Islam/NP)
# (NC Islam/NP)
# (NC San/NP)
# (NC September/NP)
# (NC Russians/NPS)
# (NC Americans/NPS)
# (NC America/NP)
# (NC Cole/NP)
# (NC China/NP)
# (NC Al/NP)
# (NC Russia/NP)
# (NC China/NP)
# (NC Russia/NP)
# (NC Russia/NP)
# (NC Russians/NPS)
# (NC America/NP)
# (NC Russia/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC America/NP)
# (NC America/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC America/NP)
# (NC V./NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC York/NP-TL)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC America/NP)
# (NC America/NP)
# (NC Pennsylvania/NP)
# (NC York/NP-TL)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Carter/NP)
# (NC Mr./NP)
# (NC Mr./NP)
# (NC Mr./NP)
# (NC Don/NP)
# (NC Ruth/NP)
# (NC Nevada/NP)
# (NC Nevada/NP)
# (NC Texas/NP)
# (NC Tennessee/NP)
# (NC Georgia/NP)
# (NC Arkansas/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Ohio/NP)
# (NC Eric/NP)
# (NC Don/NP)
# (NC Hope/NP)
# (NC Charles/NP)
# (NC Dan/NP)
# (NC Mr./NP)
# (NC Mrs./NP Phil/NP)
# (NC Phil/NP)
# (NC Donald/NP)
# (NC Donald/NP)
# (NC Phil/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Phil/NP)
# (NC Mrs./NP Steve/NP)
# (NC Steve/NP)
# (NC Steve/NP)
# (NC Steve/NP)
# (NC Donald/NP)
# (NC Phil/NP)
# (NC Steve/NP)
# (NC Robert/NP)
# (NC Jerry/NP)
# (NC Jr./NP)
# (NC Jerry/NP)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Las/NP Vegas/NP)
# (NC Steve/NP)
# (NC Las/NP Vegas/NP)
# (NC America/NP)
# (NC York/NP-TL)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Chevrolet/NP)
# (NC Tokyo/NP)
# (NC Mexico/NP-TL)
# (NC U.S./NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC America/NP)
# (NC Syria/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC China/NP)
# (NC Mexico/NP)
# (NC Vatican/NP)
# (NC Donald/NP)
# (NC Christianity/NP)
# (NC Republicans/NPS)
# (NC China/NP)
# (NC China/NP)
# (NC Potomac/NP)
# (NC Donald/NP)
# (NC America/NP)
# (NC God/NP)
# (NC China/NP)
# (NC Mexico/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Iran/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC China/NP)
# (NC Russia/NP)
# (NC China/NP)
# (NC Boeing/NP)
# (NC Boeing/NP)
# (NC China/NP)
# (NC China/NP)
# (NC America/NP-TL)
# (NC Americas/NPS)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC England/NP-TL)
# (NC Tom/NP)
# (NC China/NP)
# (NC China/NP)
# (NC George/NP Washington/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Mexico/NP-TL)
# (NC Ford/NP)
# (NC Mexico/NP-TL)
# (NC Tennessee/NP)
# (NC Tennessee/NP)
# (NC Tennessee/NP)
# (NC Mexico/NP)
# (NC Ford/NP)
# (NC Ford/NP)
# (NC Mexico/NP)
# (NC Ford/NP)
# (NC Ford/NP)
# (NC Mexico/NP)
# (NC Ford/NP)
# (NC Ford/NP)
# (NC Ford/NP)
# (NC Ford/NP)
# (NC Mexico/NP)
# (NC Ford/NP)
# (NC Ford/NP)
# (NC Mr./NP)
# (NC Mexico/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Iraq/NP)
# (NC Bush/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Ford/NP)
# (NC Mr./NP)
# (NC Brooklyn/NP-TL)
# (NC Queens/NP)
# (NC Donald/NP)
# (NC Manhattan/NP)
# (NC Manhattan/NP)
# (NC Brooklyn/NP)
# (NC Manhattan/NP)
# (NC Donald/NP)
# (NC Donald/NP)
# (NC Americas/NPS)
# (NC America/NP-TL)
# (NC San/NP Francisco/NP)
# (NC York/NP-TL)
# (NC Greece/NP)
# (NC Mr./NP)
# (NC Mr./NP)
# (NC Bush/NP)
# (NC Pennsylvania/NP)
# (NC Washington/NP)
# (NC D.C./NP)
# (NC Washington/NP)
# (NC La/NP Guardia/NP-TL)
# (NC China/NP)
# (NC Chris/NP)
# (NC Ted/NP)
# (NC Texas/NP)
# (NC Ted/NP Cruz/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Virginia/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Miami/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Ford/NP)
# (NC Mexico/NP)
# (NC Chicago/NP)
# (NC Mexico/NP)
# (NC Larry/NP)
# (NC Ireland/NP)
# (NC York/NP-TL)
# (NC Florida/NP)
# (NC Jersey/NP-TL)
# (NC Chris/NP)
# (NC Jersey/NP-TL)
# (NC Chris/NP)
# (NC Japan/NP)
# (NC June/NP)
# (NC Iran/NP)
# (NC Carolina/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Nevada/NP)
# (NC Georgia/NP)
# (NC Alabama/NP)
# (NC Massachusetts/NP)
# (NC Tennessee/NP)
# (NC Virginia/NP)
# (NC Carolina/NP-TL)
# (NC Democrat/NP)
# (NC Democrats/NPS)
# (NC Democrats/NPS)
# (NC Democrats/NPS)
# (NC Democrats/NPS)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Ted/NP)
# (NC November/NP)
# (NC Sarah/NP)
# (NC Fox/NP)
# (NC Ted/NP)
# (NC Ted/NP)
# (NC Texas/NP)
# (NC Texas/NP)
# (NC Eric/NP)
# (NC Chris/NP)
# (NC Chris/NP)
# (NC Donald/NP)
# (NC Kentucky/NP)
# (NC Alabama/NP)
# (NC Chris/NP)
# (NC Chris/NP)
# (NC ABC/NP)
# (NC George/NP)
# (NC Congress/NP)
# (NC Carl/NP)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Mexico/NP)
# (NC Nevada/NP)
# (NC Fox/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Chris/NP)
# (NC China/NP)
# (NC John/NP)
# (NC John/NP)
# (NC John/NP)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Germany/NP)
# (NC Syria/NP)
# (NC Americans/NPS)
# (NC Donald/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Don/NP)
# (NC Don/NP)
# (NC Mary/NP)
# (NC Mary/NP)
# (NC Fox/NP)
# (NC Ted/NP)
# (NC China/NP)
# (NC Asia/NP)
# (NC Hillary/NP)
# (NC Syria/NP)
# (NC Republicans/NPS)
# (NC Democrats/NPS)
# (NC David/NP)
# (NC Democrats/NPS)
# (NC Carolina/NP-TL)
# (NC Paul/NP Ryan/NP)
# (NC Mitch/NP)
# (NC York/NP-TL)
# (NC Dallas/NP)
# (NC Oklahoma/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Iowa/NP)
# (NC Hillary/NP)
# (NC Donald/NP)
# (NC Hillary/NP)
# (NC China/NP)
# (NC Carl/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Jeb/NP Bush/NP)
# (NC Bush/NP)
# (NC Fox/NP)
# (NC Matt/NP)
# (NC U.S./NP-HL)
# (NC Washington/NP)
# (NC Fox/NP)
# (NC Fox/NP Las/NP Vegas/NP)
# (NC Mr./NP)
# (NC Bush/NP)
# (NC Bush/NP)
# (NC Mr./NP)
# (NC Jeb/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Jeb/NP)
# (NC Hillary/NP)
# (NC Donald/NP)
# (NC Syria/NP)
# (NC Syria/NP)
# (NC Syria/NP)
# (NC Syria/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Mr./NP)
# (NC Fox/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Carolina/NP-TL)
# (NC Washington/NP)
# (NC Iowa/NP)
# (NC Jeb/NP)
# (NC Jeb/NP Bush/NP)
# (NC Oklahoma/NP)
# (NC Mobile/NP)
# (NC Alabama/NP)
# (NC June/NP)
# (NC Fox/NP)
# (NC Mr./NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Mr./NP)
# (NC Iran/NP)
# (NC Kerry/NP-TL)
# (NC Hillary/NP)
# (NC Libyan/NP-TL)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC Iraq/NP)
# (NC Paris/NP)
# (NC Boeing/NP)
# (NC York/NP-TL)
# (NC God/NP)
# (NC Korea/NP-TL)
# (NC China/NP)
# (NC Miss/NP)
# (NC Miss/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Korea/NP-TL)
# (NC Korea/NP-TL)
# (NC Korea/NP-TL)
# (NC Korea/NP-TL)
# (NC Korea/NP-TL)
# (NC Germany/NP)
# (NC Germany/NP)
# (NC Germany/NP)
# (NC Saudi/NP Arabia/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC York/NP-TL)
# (NC Mr./NP)
# (NC America/NP-TL)
# (NC China/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC China/NP)
# (NC Mexico/NP-TL)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Carl/NP)
# (NC Carl/NP)
# (NC Carl/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Jeb/NP Bush/NP)
# (NC Syria/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Germany/NP)
# (NC Syria/NP)
# (NC Germany/NP)
# (NC Germany/NP)
# (NC Mr./NP)
# (NC Iowa/NP)
# (NC Republicans/NPS)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Ted/NP Cruz/NP)
# (NC Fox/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Kate/NP)
# (NC San/NP Francisco/NP)
# (NC Los/NP Angeles/NP)
# (NC Shaw/NP)
# (NC Kate/NP)
# (NC Hillary/NP)
# (NC Chuck/NP)
# (NC Hillary/NP)
# (NC Donald/NP)
# (NC Hillary/NP)
# (NC Chuck/NP)
# (NC Chuck/NP)
# (NC Chuck/NP)
# (NC Hillary/NP)
# (NC Chuck/NP)
# (NC Paris/NP)
# (NC Los/NP Angeles/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC France/NP)
# (NC Los/NP Angeles/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC California/NP)
# (NC Paris/NP)
# (NC California/NP)
# (NC Ford/NP)
# (NC Mexico/NP)
# (NC Michigan/NP)
# (NC Mexico/NP)
# (NC Michigan/NP)
# (NC Ford/NP)
# (NC Chicago/NP)
# (NC Chicago/NP)
# (NC Mexico/NP-TL)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iran/NP Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC February/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC America/NP)
# (NC Carolina/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Texas/NP)
# (NC Nevada/NP)
# (NC Nevada/NP)
# (NC Atlanta/NP)
# (NC Nevada/NP)
# (NC Carolina/NP-TL)
# (NC Don/NP)
# (NC Henry/NP)
# (NC Carolina/NP-TL)
# (NC Eric/NP)
# (NC M./NP)
# (NC Carolina/NP-TL)
# (NC Nevada/NP)
# (NC I./NP)
# (NC Carolina/NP-TL)
# (NC America/NP)
# (NC Ted/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mr./NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC China/NP)
# (NC Nevada/NP)
# (NC Mexico/NP-TL)
# (NC Japan/NP)
# (NC Viet/NP-TL Nam/NP-TL)
# (NC China/NP)
# (NC China/NP)
# (NC Carl/NP)
# (NC China/NP)
# (NC Washington/NP)
# (NC China/NP)
# (NC Denmark/NP)
# (NC Washington/NP)
# (NC Washington/NP)
# (NC Nevada/NP)
# (NC Mobile/NP)
# (NC Alabama/NP)
# (NC Oklahoma/NP)
# (NC Dallas/NP)
# (NC America/NP)
# (NC America/NP)
# (NC June/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC America/NP)
# (NC San/NP Francisco/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexican/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Donald/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC God/NP)
# (NC Hillary/NP)
# (NC Orlando/NP-HL)
# (NC Florida/NP)
# (NC September/NP)
# (NC Americans/NPS)
# (NC America/NP)
# (NC Afghan/NP)
# (NC Afghan/NP)
# (NC Afghan/NP)
# (NC America/NP)
# (NC San/NP)
# (NC Europe/NP)
# (NC America/NP)
# (NC Islam/NP)
# (NC Islam/NP)
# (NC America/NP)
# (NC Americans/NPS)
# (NC Jews/NPS)
# (NC Christians/NPS)
# (NC Islam/NP)
# (NC Islam/NP)
# (NC America/NP)
# (NC September/NP)
# (NC Minnesota/NP)
# (NC Boston/NP)
# (NC San/NP)
# (NC Pakistan/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Hillary/NP)
# (NC Islam/NP)
# (NC Islam/NP)
# (NC San/NP)
# (NC Hillary/NP)
# (NC Islam/NP)
# (NC Muslims/NPS)
# (NC Hillary/NP)
# (NC France/NP)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Hillary/NP)
# (NC Islam/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC September/NP)
# (NC September/NP)
# (NC America/NP)
# (NC Orlando/NP-HL)
# (NC Islam/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Americans/NPS)
# (NC Hillary/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC Boston/NP)
# (NC Orlando/NP-HL)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Donald/NP)
# (NC Hillary/NP)
# (NC Americans/NPS)
# (NC Republican/NP)
# (NC Muslims/NPS)
# (NC Muslims/NPS)
# (NC San/NP)
# (NC Hillary/NP)
# (NC San/NP)
# (NC America/NP)
# (NC Orlando/NP-HL)
# (NC Syria/NP)
# (NC Iran/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC Orlando/NP-HL)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Israel/NP)
# (NC York/NP-TL)
# (NC Washington/NP)
# (NC Rudy/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP-TL)
# (NC Iran/NP)
# (NC America/NP)
# (NC Israel/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Israel/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Syria/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Iran/NP)
# (NC Syria/NP)
# (NC Israel/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Israel/NP)
# (NC Europe/NP)
# (NC Israel/NP)
# (NC Hebrew/NP)
# (NC Israel/NP)
# (NC Hebrew/NP)
# (NC America/NP-TL)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Palestine/NP)
# (NC Israel/NP)
# (NC Palestine/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Americans/NPS)
# (NC Taylor/NP Allen/NP)
# (NC Iraq/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC David/NP)
# (NC John/NP Kerry/NP-TL)
# (NC America/NP-TL)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Jews/NPS)
# (NC Jews/NPS)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Hillary/NP)
# (NC Israel/NP)
# (NC America/NP)
# (NC Iran/NP)
# (NC Israel/NP)
# (NC Palestine/NP)
# (NC Israel/NP)
# (NC Donald/NP)
# (NC Jerusalem/NP)
# (NC America/NP)
# (NC Israel/NP-TL)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Montana/NP)
# (NC Dakota/NP-TL)
# (NC Mexico/NP-TL)
# (NC Jersey/NP-TL)
# (NC California/NP)
# (NC Hillary/NP)
# (NC Republican/NP)
# (NC Democrat/NP)
# (NC Hillary/NP)
# (NC Russians/NPS)
# (NC Chinese/NPS)
# (NC Bill/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC York/NP-TL)
# (NC Jersey/NP-TL)
# (NC Pennsylvania/NP)
# (NC Connecticut/NP)
# (NC Indiana/NP)
# (NC Ohio/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Iraq/NP)
# (NC Syria/NP)
# (NC Iran/NP)
# (NC America/NP)
# (NC Bill/NP)
# (NC Mexico/NP-TL)
# (NC America/NP)
# (NC America/NP)
# (NC Americans/NPS)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC Orlando/NP-HL)
# (NC Florida/NP)
# (NC September/NP)
# (NC Orlando/NP-HL)
# (NC Americans/NPS)
# (NC America/NP)
# (NC Afghan/NP)
# (NC Afghan/NP)
# (NC America/NP)
# (NC San/NP)
# (NC Europe/NP)
# (NC America/NP)
# (NC Islam/NP)
# (NC Islam/NP)
# (NC America/NP)
# (NC Americans/NPS)
# (NC Jews/NPS)
# (NC Christians/NPS)
# (NC Islam/NP)
# (NC Islam/NP)
# (NC America/NP)
# (NC September/NP)
# (NC Minnesota/NP)
# (NC Boston/NP)
# (NC San/NP)
# (NC Pakistan/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Hillary/NP)
# (NC Islam/NP)
# (NC Hillary/NP)
# (NC Islam/NP)
# (NC San/NP)
# (NC Hillary/NP)
# (NC Islam/NP)
# (NC Muslims/NPS)
# (NC Hillary/NP)
# (NC France/NP)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Hillary/NP)
# (NC Islam/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC September/NP)
# (NC America/NP)
# (NC Orlando/NP-HL)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Americans/NPS)
# (NC Hillary/NP)
# (NC Americans/NPS)
# (NC America/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC Boston/NP)
# (NC Orlando/NP-HL)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Donald/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC San/NP)
# (NC America/NP)
# (NC Syria/NP)
# (NC Iran/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC Orlando/NP-HL)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC January/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Ted/NP Cruz/NP)
# (NC America/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Ford/NP)
# (NC Tennessee/NP)
# (NC Paris/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Paris/NP)
# (NC Dallas/NP)
# (NC Mobile/NP)
# (NC Alabama/NP)
# (NC Oklahoma/NP)
# (NC Iowa/NP)
# (NC Paris/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Bing/NP)
# (NC Jacobs/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Georgia/NP)
# (NC York/NP-TL)
# (NC Iowa/NP)
# (NC Billy/NP Graham/NP)
# (NC Franklin/NP Graham/NP)
# (NC Franklin/NP Graham/NP)
# (NC Franklin/NP Graham/NP)
# (NC Billy/NP Graham/NP)
# (NC Billy/NP Graham/NP)
# (NC Ted/NP Cruz/NP)
# (NC Cuba/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Carolina/NP-TL)
# (NC Nevada/NP)
# (NC Texas/NP)
# (NC Florida/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Mr./NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC China/NP)
# (NC China/NP)
# (NC George/NP Washington/NP)
# (NC George/NP Washington/NP)
# (NC China/NP)
# (NC Carl/NP)
# (NC Donald/NP)
# (NC China/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Democrats/NPS)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC Paris/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC MacArthur/NP)
# (NC Douglas/NP MacArthur/NP)
# (NC George/NP Patton/NP)
# (NC France/NP)
# (NC California/NP)
# (NC York/NP-TL)
# (NC France/NP)
# (NC California/NP)
# (NC France/NP)
# (NC Paris/NP)
# (NC France/NP)
# (NC California/NP)
# (NC Paris/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Ted/NP Cruz/NP)
# (NC Ted/NP)
# (NC Donald/NP)
# (NC Bush/NP)
# (NC Bush/NP)
# (NC Los/NP-TL Angeles/NP-TL)
# (NC Cruz/NP)
# (NC Texas/NP)
# (NC Texas/NP)
# (NC Iowa/NP)
# (NC Ted/NP Cruz/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Republican/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Jay/NP)
# (NC David/NP)
# (NC Ford/NP)
# (NC Mexico/NP)
# (NC Michigan/NP)
# (NC Mexico/NP-TL)
# (NC Mr./NP)
# (NC Hollywood/NP)
# (NC Bill/NP)
# (NC Dallas/NP)
# (NC Mobile/NP)
# (NC Oklahoma/NP)
# (NC Germany/NP)
# (NC Syria/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Jeb/NP)
# (NC Washington/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Iowa/NP)
# (NC Pennsylvania/NP)
# (NC Mr./NP)
# (NC China/NP)
# (NC America/NP-TL)
# (NC Mexico/NP-TL)
# (NC China/NP)
# (NC Montana/NP)
# (NC Dakota/NP-TL)
# (NC Mexico/NP-TL)
# (NC Jersey/NP-TL)
# (NC California/NP)
# (NC Hillary/NP)
# (NC Republican/NP)
# (NC Democrat/NP)
# (NC Hillary/NP)
# (NC Russians/NPS)
# (NC Chinese/NPS)
# (NC Bill/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC York/NP-TL)
# (NC Jersey/NP-TL)
# (NC Pennsylvania/NP)
# (NC Connecticut/NP)
# (NC Indiana/NP)
# (NC Ohio/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Iraq/NP)
# (NC Syria/NP)
# (NC Iran/NP)
# (NC America/NP)
# (NC Bill/NP)
# (NC Mexico/NP-TL)
# (NC America/NP)
# (NC America/NP)
# (NC Americans/NPS)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Cleveland/NP)
# (NC Cleveland/NP)
# (NC Dwight/NP Eisenhower/NP)
# (NC Hillary/NP)
# (NC November/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC Iowa/NP)
# (NC Mr./NP)
# (NC Achilles/NP)
# (NC Americans/NPS)
# (NC Fox/NP)
# (NC Fox/NP)
# (NC Carl/NP)
# (NC Phil/NP)
# (NC Ike/NP-TL)
# (NC Hillary/NP)
# (NC Donald/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Jefferson/NP)
# (NC Donald/NP)
# (NC Donald/NP)
# (NC Jefferson/NP)
# (NC Lincoln/NP)
# (NC Eugene/NP Washington/NP)
# (NC Jefferson/NP)
# (NC Washington/NP)
# (NC ABC/NP)
# (NC Mr./NP)
# (NC Hampshire/NP-TL)
# (NC Donald/NP)
# (NC Donald/NP)
# (NC Al/NP)
# (NC Al/NP)
# (NC Hampshire/NP-TL)
# (NC Hillary/NP)
# (NC Jeff/NP)
# (NC Jeff/NP)
# (NC Jeff/NP)
# (NC Ted/NP Cruz/NP)
# (NC Ted/NP)
# (NC Jeff/NP)
# (NC Jeff/NP)
# (NC Phoenix/NP)
# (NC Hillary/NP)
# (NC Bob/NP)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Democrats/NPS)
# (NC Texas/NP)
# (NC Texas/NP)
# (NC Bill/NP)
# (NC Donald/NP)
# (NC Republicans/NPS)
# (NC Bill/NP)
# (NC Bill/NP)
# (NC Bill/NP)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Hillary/NP)
# (NC Republican/NP)
# (NC Bob/NP)
# (NC Bob/NP)
# (NC Bob/NP)
# (NC Gary/NP Johnson/NP)
# (NC Elizabeth/NP)
# (NC Robert/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Indiana/NP-TL)
# (NC Bobby/NP)
# (NC Bobby/NP)
# (NC Indiana/NP-TL)
# (NC Florida/NP)
# (NC Nebraska/NP)
# (NC Virginia/NP-TL)
# (NC Hillary/NP)
# (NC Virginia/NP-TL)
# (NC Pennsylvania/NP)
# (NC Ohio/NP)
# (NC York/NP-TL)
# (NC York/NP-TL)
# (NC Hillary/NP)
# (NC Syracuse/NP)
# (NC Poughkeepsie/NP)
# (NC York/NP-TL)
# (NC Pennsylvania/NP)
# (NC Maryland/NP)
# (NC Connecticut/NP)
# (NC Ted/NP Cruz/NP)
# (NC Ted/NP)
# (NC Ted/NP)
# (NC Chris/NP)
# (NC Ben/NP Carson/NP)
# (NC Ben/NP Carson/NP)
# (NC Ben/NP)
# (NC November/NP)
# (NC America/NP)
# (NC China/NP)
# (NC Hillary/NP)
# (NC Paul/NP)
# (NC Pope/NP)
# (NC Ted/NP)
# (NC Mr./NP)
# (NC Jeff/NP)
# (NC Jeff/NP)
# (NC Congress/NP)
# (NC Sarah/NP)
# (NC Jerry/NP)
# (NC Jr./NP)
# (NC Christmas/NP)
# (NC Ted/NP Cruz/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Miss/NP Wisconsin/NP)
# (NC Melissa/NP)
# (NC Cruz/NP)
# (NC Wisconsin/NP)
# (NC Cruz/NP)
# (NC Florida/NP)
# (NC Ohio/NP)
# (NC Jeb/NP Bush/NP)
# (NC Paul/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Melissa/NP Young/NP)
# (NC Melissa/NP Young/NP)
# (NC Melissa/NP)
# (NC Melissa/NP)
# (NC Cruz/NP)
# (NC Wisconsin/NP)
# (NC Ted/NP Cruz/NP)
# (NC Cruz/NP)
# (NC Washington/NP)
# (NC Cruz/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Boeing/NP)
# (NC MacArthur/NP)
# (NC George/NP Patton/NP)
# (NC June/NP)
# (NC Louisiana/NP)
# (NC Cruz/NP)
# (NC Wisconsin/NP)
# (NC China/NP)
# (NC Mexico/NP)
# (NC Joe/NP)
# (NC Arizona/NP)
# (NC Arizona/NP)
# (NC Joe/NP)
# (NC Syrians/NP)
# (NC Syrians/NP)
# (NC Syria/NP)
# (NC Al/NP Green/NP)
# (NC Al/NP Green/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC China/NP)
# (NC Wisconsin/NP)
# (NC Ford/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Chicago/NP)
# (NC Mexico/NP)
# (NC Ireland/NP)
# (NC Donald/NP)
# (NC Washington/NP)
# (NC June/NP)
# (NC Wisconsin/NP)
# (NC U.S./NP)
# (NC U.S./NP)
# (NC Cruz/NP)
# (NC Ted/NP)
# (NC Ben/NP Carson/NP)
# (NC Ben/NP Carson/NP)
# (NC Ted/NP)
# (NC Iowa/NP)
# (NC Ben/NP)
# (NC Ben/NP)
# (NC Ted/NP Cruz/NP)
# (NC Ted/NP)
# (NC Jerry/NP)
# (NC Jr./NP)
# (NC Bible/NP)
# (NC Ted/NP)
# (NC Fox/NP)
# (NC Mexico/NP-TL)
# (NC Jeb/NP Bush/NP)
# (NC Ted/NP Cruz/NP)
# (NC NATO/NP-TL)
# (NC Wolf/NP)
# (NC NATO/NP-TL)
# (NC Washington/NP)
# (NC Wolf/NP)
# (NC NATO/NP-TL)
# (NC NATO/NP-TL)
# (NC NATO/NP-TL)
# (NC Russia/NP)
# (NC Russia/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Korea/NP-TL)
# (NC Korea/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Los/NP Angeles/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Germany/NP)
# (NC Korea/NP)
# (NC Korea/NP-TL)
# (NC Korea/NP-TL)
# (NC Washington/NP)
# (NC Iran/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Korea/NP-TL)
# (NC Japan/NP)
# (NC Iran/NP)
# (NC Kerry/NP-TL)
# (NC Iran/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Cruz/NP)
# (NC Republicans/NPS)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Korea/NP-TL)
# (NC Korea/NP-TL)
# (NC Saudi/NP Arabia/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Germany/NP)
# (NC Germany/NP)
# (NC Mr./NP)
# (NC Hillary/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Jeb/NP)
# (NC Hampshire/NP-TL)
# (NC Mr./NP)
# (NC Hampshire/NP-TL)
# (NC Donald/NP)
# (NC Donald/NP)
# (NC Donald/NP)
# (NC Cruz/NP)
# (NC Ted/NP)
# (NC Ted/NP Cruz/NP)
# (NC Bible/NP)
# (NC Donald/NP)
# (NC Wisconsin/NP)
# (NC Scott/NP)
# (NC Walker/NP)
# (NC Wisconsin/NP)
# (NC Wisconsin/NP)
# (NC Wisconsin/NP)
# (NC Cruz/NP)
# (NC Wisconsin/NP-TL)
# (NC Mexico/NP-TL)
# (NC Wisconsin/NP)
# (NC Hilton/NP-TL)
# (NC America/NP)
# (NC China/NP)
# (NC Wisconsin/NP)
# (NC Walker/NP)
# (NC China/NP)
# (NC Mexico/NP)
# (NC Japan/NP)
# (NC Vietnam/NP-TL)
# (NC China/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Ford/NP)
# (NC Mexico/NP-TL)
# (NC Wisconsin/NP)
# (NC Emerson/NP)
# (NC York/NP-TL)
# (NC Cruz/NP)
# (NC York/NP-TL)
# (NC Yorkers/NPS)
# (NC Yorkers/NPS)
# (NC Yorkers/NPS)
# (NC Yorkers/NPS)
# (NC Yorkers/NPS-TL)
# (NC Cruz/NP)
# (NC York/NP-TL)
# (NC Jersey/NP-TL)
# (NC Chris/NP)
# (NC Jersey/NP-TL)
# (NC Ben/NP Carson/NP)
# (NC Sarah/NP)
# (NC Joe/NP)
# (NC Arizona/NP)
# (NC Joe/NP)
# (NC Jerry/NP)
# (NC Jr./NP)
# (NC Christians/NPS)
# (NC Carolina/NP-TL)
# (NC Carolina/NP-TL)
# (NC Wisconsin/NP)
# (NC Wisconsin/NP)
# (NC Jeb/NP)
# (NC Cruz/NP)
# (NC Joe/NP)
# (NC Joe/NP)
# (NC Hillary/NP)
# (NC Donald/NP)
# (NC Donald/NP)
# (NC Chuck/NP)
# (NC Chuck/NP)
# (NC Donald/NP)
# (NC Ted/NP Cruz/NP)
# (NC Cruz/NP)
# (NC Hillary/NP)
# (NC Jeb/NP)
# (NC Hampshire/NP-TL)
# (NC Jeb/NP)
# (NC Jeb/NP)
# (NC Jeb/NP)
# (NC Cruz/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Syria/NP)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Christianity/NP)
# (NC Christianity/NP)
# (NC Jerry/NP)
# (NC Jr./NP)
# (NC Jerry/NP)
# (NC Jerry/NP)
# (NC Lyndon/NP Johnson/NP)
# (NC Christianity/NP)
# (NC Johnson/NP)
# (NC Christians/NPS)
# (NC Christianity/NP)
# (NC Christians/NPS)
# (NC Christians/NPS)
# (NC Christians/NPS)
# (NC Muslims/NPS)
# (NC Christians/NPS)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Florida/NP)
# (NC Cruz/NP)
# (NC Don/NP)
# (NC Florida/NP)
# (NC Ohio/NP)
# (NC Ohio/NP)
# (NC Ohio/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Wisconsin/NP)
# (NC Cruz/NP)
# (NC Cruz/NP)
# (NC Jeff/NP)
# (NC Jeff/NP)
# (NC Cruz/NP)
# (NC Jeff/NP)
# (NC Lee/NP)
# (NC Cruz/NP)
# (NC Mitch/NP)
# (NC Mitch/NP)
# (NC Paul/NP Ryan/NP)
# (NC Paul/NP Ryan/NP)
# (NC Republicans/NPS)
# (NC Walker/NP)
# (NC Walker/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Walker/NP)
# (NC America/NP)
# (NC Wisconsin/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC York/NP-TL)
# (NC San/NP Francisco/NP)
# (NC America/NP-TL)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Mexico/NP)
# (NC Green/NP)
# (NC Tom/NP)
# (NC Tom/NP)
# (NC Wisconsin/NP)
# (NC Wisconsin/NP)
# (NC Iran/NP)
# (NC Cruz/NP)
# (NC Phoenix/NP)
# (NC Joe/NP)
# (NC Cruz/NP)
# (NC China/NP)
# (NC Mexico/NP)
# (NC Wisconsin/NP)
# (NC Washington/NP)
# (NC D.C./NP)
# (NC Washington/NP)
# (NC Washington/NP)
# (NC Denmark/NP)
# (NC China/NP)
# (NC Wisconsin/NP)
# (NC Jupiter/NP)
# (NC Florida/NP)
# (NC Cruz/NP)
# (NC John/NP)
# (NC Wisconsin/NP)
# (NC Mr./NP)
# (NC March/NP)
# (NC Mr./NP)
# (NC God/NP)
# (NC Miss/NP-TL)
# (NC Miss/NP)
# (NC Miss/NP)
# (NC Miss/NP)
# (NC Cruz/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Adam/NP Scott/NP)
# (NC Adam/NP Scott/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC God/NP)
# (NC Wisconsin/NP)
# (NC Florida/NP)
# (NC Canada/NP)
# (NC Cruz/NP)
# (NC Texas/NP)
# (NC Democrats/NPS)
# (NC Ted/NP Cruz/NP)
# (NC Canada/NP)
# (NC Harvard/NP-TL)
# (NC Cruz/NP)
# (NC Cruz/NP)
# (NC Democrats/NPS)
# (NC U.S./NP)
# (NC Texas/NP)
# (NC Sarah/NP)
# (NC Sarah/NP)
# (NC Texas/NP)
# (NC Canada/NP)
# (NC Canada/NP)
# (NC America/NP)
# (NC Carolina/NP-TL)
# (NC Illinois/NP)
# (NC Florida/NP)
# (NC Ralph/NP)
# (NC James/NP)
# (NC Ada/NP)
# (NC Donald/NP)
# (NC Eric/NP)
# (NC Don/NP)
# (NC Ohio/NP)
# (NC China/NP)
# (NC Vietnam/NP-TL)
# (NC Ford/NP)
# (NC Cleveland/NP)
# (NC Ireland/NP)
# (NC Democrat/NP)
# (NC Republican/NP)
# (NC Ben/NP Carson/NP)
# (NC Chris/NP)
# (NC Pam/NP Bondi/NP)
# (NC Florida/NP)
# (NC Paul/NP Ryan/NP)
# (NC Mitch/NP)
# (NC Europe/NP)
# (NC Democrats/NPS)
# (NC Sarah/NP)
# (NC Hope/NP)
# (NC June/NP)
# (NC Iran/NP)
# (NC China/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC Los/NP Angeles/NP)
# (NC California/NP)
# (NC Carl/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP-TL)
# (NC Vietnam/NP-TL)
# (NC India/NP)
# (NC Florida/NP)
# (NC Adam/NP Scott/NP)
# (NC Adam/NP)
# (NC Cadillac/NP)
# (NC Adam/NP)
# (NC Australia/NP)
# (NC Australia/NP)
# (NC Adam/NP Scott/NP)
# (NC Hillary/NP)
# (NC Republican/NP)
# (NC Republicans/NPS)
# (NC Republicans/NPS)
# (NC Republicans/NPS)
# (NC Donald/NP)
# (NC Donald/NP)
# (NC Carolina/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Republicans/NPS)
# (NC Carolina/NP-TL)
# (NC Nevada/NP)
# (NC Bush/NP)
# (NC Nevada/NP)
# (NC Bush/NP)
# (NC Nevada/NP)
# (NC Hampshire/NP-TL)
# (NC Iowa/NP)
# (NC Ben/NP Carson/NP)
# (NC Cruz/NP)
# (NC Cruz/NP)
# (NC Ben/NP Carson/NP)
# (NC Bible/NP)
# (NC Carson/NP)
# (NC America/NP)
# (NC America/NP)
# (NC China/NP)
# (NC Denmark/NP)
# (NC Congress/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC Iran/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Chicago/NP)
# (NC Mexico/NP-TL)
# (NC Ford/NP)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Donald/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Yen/NP)
# (NC Donald/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Boeing/NP)
# (NC Boeing/NP)
# (NC Boeing/NP)
# (NC Boeing/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Boeing/NP)
# (NC Boeing/NP)
# (NC Boeing/NP)
# (NC Carolina/NP-TL)
# (NC China/NP)
# (NC Carl/NP)
# (NC Carl/NP)
# (NC Carl/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC America/NP-TL)
# (NC California/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC China/NP)
# (NC Germany/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Korea/NP-TL)
# (NC Korea/NP)
# (NC Korea/NP-TL)
# (NC Korea/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Carolina/NP-TL)
# (NC Carolina/NP-TL)
# (NC Carolina/NP-TL)
# (NC Germany/NP)
# (NC June/NP)
# (NC Kate/NP)
# (NC San/NP Francisco/NP)
# (NC Kate/NP)
# (NC Los/NP Angeles/NP)
# (NC Los/NP Angeles/NP)
# (NC America/NP)
# (NC America/NP)
# (NC June/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC America/NP)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Arkansas/NP)
# (NC Carolina/NP-TL)
# (NC Carolina/NP-TL)
# (NC America/NP)
# (NC Scott/NP)
# (NC Scott/NP)
# (NC Iowa/NP)
# (NC Republican/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Ted/NP Cruz/NP)
# (NC Ben/NP Carson/NP)
# (NC Ben/NP Carson/NP)
# (NC Iowa/NP)
# (NC Mike/NP)
# (NC Scott/NP Brown/NP)
# (NC Scott/NP)
# (NC Iowa/NP)
# (NC Democrats/NPS)
# (NC Democrats/NPS)
# (NC Ted/NP Cruz/NP)
# (NC Ben/NP Carson/NP)
# (NC Ben/NP Carson/NP)
# (NC Iowa/NP)
# (NC Ben/NP Carson/NP)
# (NC Ben/NP)
# (NC Iowa/NP)
# (NC June/NP)
# (NC America/NP)
# (NC Nevada/NP)
# (NC Steve/NP Burke/NP)
# (NC Donald/NP)
# (NC Steve/NP)
# (NC Jeb/NP)
# (NC Washington/NP)
# (NC Carolina/NP-TL)
# (NC Florida/NP)
# (NC Georgia/NP)
# (NC Connecticut/NP)
# (NC Tom/NP)
# (NC Tom/NP)
# (NC Maryland/NP)
# (NC Maryland/NP)
# (NC Iowa/NP)
# (NC Chris/NP)
# (NC Cruz/NP)
# (NC Cruz/NP)
# (NC Cruz/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Feb./NP)
# (NC Maine/NP)
# (NC England/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Tennessee/NP)
# (NC Texas/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC America/NP)
# (NC June/NP)
# (NC Jeb/NP)
# (NC Bush/NP)
# (NC Bush/NP)
# (NC Jeb/NP)
# (NC Jeb/NP Bush/NP)
# (NC George/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Syria/NP)
# (NC Syria/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Syria/NP)
# (NC Ford/NP)
# (NC Mexico/NP-TL)
# (NC Chicago/NP)
# (NC Mexico/NP-TL)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC Los/NP Angeles/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC California/NP)
# (NC John/NP Wayne/NP-HL)
# (NC John/NP Wayne/NP-HL)
# (NC Iowa/NP)
# (NC John/NP Wayne/NP-HL)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Christmas/NP)
# (NC Jeb/NP)
# (NC China/NP)
# (NC Washington/NP)
# (NC Iowa/NP)
# (NC Washington/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Sarah/NP)
# (NC Jeb/NP)
# (NC Hillary/NP)
# (NC Mr./NP)
# (NC Syria/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Cruz/NP)
# (NC Carson/NP)
# (NC Bush/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Bing/NP)
# (NC June/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC George/NP Patton/NP)
# (NC Douglas/NP-TL MacArthur/NP)
# (NC Bush/NP)
# (NC Bush/NP)
# (NC Donald/NP)
# (NC Hillary/NP)
# (NC Mr./NP)
# (NC Hillary/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP)
# (NC Hillary/NP)
# (NC Perry/NP)
# (NC Walker/NP)
# (NC Graham/NP)
# (NC Graham/NP)
# (NC John/NP)
# (NC John/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Mr./NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC America/NP)
# (NC California/NP)
# (NC Americans/NPS)
# (NC Muslims/NPS)
# (NC Muslims/NPS)
# (NC Muslims/NPS)
# (NC Columbus/NP-TL)
# (NC Ohio/NP)
# (NC Katie/NP)
# (NC Katie/NP)
# (NC Iran/NP)
# (NC Kerry/NP-TL)
# (NC Fox/NP)
# (NC Hillary/NP)
# (NC Donald/NP J./NP)
# (NC Donald/NP J./NP)
# (NC Muslims/NPS)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Muslims/NPS)
# (NC America/NP)
# (NC Americans/NPS)
# (NC Mr./NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC France/NP)
# (NC California/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC Paris/NP)
# (NC Bill/NP)
# (NC Pakistan/NP)
# (NC Saudi/NP Arabia/NP)
# (NC California/NP)
# (NC Dallas/NP)
# (NC Dallas/NP)
# (NC Mobile/NP)
# (NC Alabama/NP)
# (NC Carolina/NP-TL)
# (NC Carolina/NP-TL)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Virginia/NP)
# (NC Florida/NP)
# (NC Oklahoma/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC Bush/NP)
# (NC Cruz/NP)
# (NC Chris/NP)
# (NC Muslims/NPS)
# (NC Chris/NP)
# (NC George/NP Washington/NP)
# (NC George/NP Washington/NP)
# (NC Chris/NP)
# (NC George/NP Washington/NP)
# (NC Chris/NP)
# (NC Perry/NP)
# (NC Perry/NP)
# (NC America/NP-TL)
# (NC San/NP Francisco/NP)
# (NC Potomac/NP)
# (NC Carolina/NP-TL)
# (NC Graham/NP)
# (NC Kate/NP)
# (NC California/NP)
# (NC Wollman/NP)
# (NC York/NP-TL)
# (NC Ed/NP)
# (NC Bronx/NP)
# (NC Pennsylvania/NP)
# (NC September/NP)
# (NC Pennsylvania/NP)
# (NC Carl/NP)
# (NC Carolina/NP-TL)
# (NC York/NP-TL)
# (NC Florida/NP)
# (NC Carolina/NP-TL)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Washington/NP)
# (NC America/NP)
# (NC Carolina/NP-TL)
# (NC Israel/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Hillary/NP)
# (NC Fox/NP)
# (NC Fred/NP)
# (NC Brooklyn/NP)
# (NC Queens/NP)
# (NC Israel/NP)
# (NC Christians/NPS)
# (NC Christians/NPS)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC York/NP-TL)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC John/NP Kerry/NP-TL)
# (NC U.S./NP)
# (NC David/NP)
# (NC Hillary/NP)
# (NC Manassas/NP)
# (NC Virginia/NP)
# (NC Florida/NP)
# (NC John/NP)
# (NC John/NP)
# (NC Israel/NP)
# (NC Scotland/NP)
# (NC Manhattan/NP)
# (NC America/NP-TL)
# (NC San/NP Francisco/NP)
# (NC Kerry/NP-TL)
# (NC Republicans/NPS)
# (NC Democrats/NPS)
# (NC Republican/NP)
# (NC Washington/NP)
# (NC Washington/NP)
# (NC Israel/NP)
# (NC Jeb/NP Bush/NP)
# (NC Israel/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Iran/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Iowa/NP)
# (NC February/NP)
# (NC Arab/NP)
# (NC Jordan/NP)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Manhattan/NP)
# (NC Democrat/NP)
# (NC Republicans/NPS)
# (NC Washington/NP)
# (NC Republicans/NPS)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Democrats/NPS)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC George/NP Patton/NP)
# (NC MacArthur/NP)
# (NC George/NP Patton/NP)
# (NC Patton/NP)
# (NC MacArthur/NP)
# (NC Islam/NP)
# (NC Islam/NP)
# (NC Paris/NP)
# (NC Simon/NP)
# (NC Simon/NP)
# (NC Rolls-Royce/NP)
# (NC Harvard/NP-TL)
# (NC Yale/NP-TL)
# (NC America/NP)
# (NC America/NP)
# (NC Simon/NP)
# (NC David/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Florida/NP)
# (NC Georgia/NP)
# (NC Texas/NP)
# (NC Ben/NP)
# (NC Simon/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP-TL)
# (NC Ben/NP)
# (NC Ben/NP)
# (NC Bush/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Bush/NP)
# (NC Mr./NP Singer/NP)
# (NC Mr./NP Singer/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Hillary/NP)
# (NC Republicans/NPS)
# (NC Republicans/NPS)
# (NC Hollywood/NP)
# (NC Jeb/NP Bush/NP)
# (NC Nevada/NP)
# (NC Nevada/NP)
# (NC Hillary/NP)
# (NC Jeb/NP)
# (NC Tom/NP)
# (NC Jeb/NP)
# (NC Jeb/NP)
# (NC Ben/NP Carson/NP)
# (NC Jeb/NP)
# (NC Scotland/NP)
# (NC Mexico/NP)
# (NC Asia/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Iran/NP)
# (NC Hillary/NP)
# (NC Bill/NP)
# (NC Democrats/NPS)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Russia/NP)
# (NC Russia/NP)
# (NC Russia/NP)
# (NC Russia/NP)
# (NC Iraq/NP)
# (NC July/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Republicans/NPS)
# (NC Republican/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Georgia/NP)
# (NC Mark/NP)
# (NC Scott/NP)
# (NC Walker/NP)
# (NC Walker/NP)
# (NC Walker/NP)
# (NC Walker/NP)
# (NC Fortune/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Mark/NP)
# (NC America/NP)
# (NC Simon/NP)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Democrats/NPS)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Mr./NP Singer/NP)
# (NC Mr./NP Singer/NP)
# (NC Carl/NP)
# (NC John/NP)
# (NC Carl/NP)
# (NC John/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC Simon/NP)
# (NC America/NP)
# (NC Simon/NP)
# (NC Republicans/NPS)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Iowa/NP)
# (NC Miami/NP)
# (NC Scotland/NP)
# (NC Hillary/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC Mexico/NP)
# (NC Chicago/NP)
# (NC Mexico/NP)
# (NC Carl/NP)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC Democrats/NPS)
# (NC Republicans/NPS)
# (NC York/NP-TL)
# (NC Florida/NP)
# (NC Texas/NP)
# (NC Jersey/NP-TL)
# (NC Ireland/NP)
# (NC China/NP)
# (NC Mexico/NP-TL)
# (NC Japan/NP)
# (NC Los/NP Angeles/NP)
# (NC Japan/NP)
# (NC Jack/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Carl/NP)
# (NC Carl/NP)
# (NC Carl/NP)
# (NC China/NP)
# (NC Carl/NP)
# (NC Korea/NP-TL)
# (NC Japan/NP)
# (NC Korea/NP-TL)
# (NC George/NP)
# (NC Carolina/NP-TL)
# (NC Carolina/NP-TL)
# (NC Korea/NP)
# (NC Korea/NP)
# (NC Korea/NP-TL)
# (NC Iran/NP)
# (NC Syria/NP)
# (NC Dwight/NP Eisenhower/NP)
# (NC Dwight/NP)
# (NC Ike/NP-TL)
# (NC MacArthur/NP)
# (NC Patton/NP)
# (NC Ike/NP-TL)
# (NC Patton/NP)
# (NC MacArthur/NP)
# (NC Patton/NP)
# (NC Patton/NP)
# (NC MacArthur/NP)
# (NC Iraq/NP)
# (NC God/NP)
# (NC God/NP)
# (NC Iraq/NP)
# (NC Bush/NP)
# (NC Mr./NP)
# (NC Iowa/NP)
# (NC Bible/NP)
# (NC Bible/NP)
# (NC Mary/NP)
# (NC Bible/NP)
# (NC Iowa/NP)
# (NC Carson/NP)
# (NC Ben/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC Ben/NP)
# (NC Ben/NP)
# (NC Iowa/NP)
# (NC Jeb/NP Bush/NP)
# (NC Bush/NP)
# (NC Walker/NP)
# (NC Ben/NP)
# (NC Bush/NP)
# (NC John/NP)
# (NC John/NP)
# (NC John/NP)
# (NC John/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC John/NP)
# (NC John/NP)
# (NC Mr./NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Carolina/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Carolina/NP-TL)
# (NC Nevada/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Carolina/NP)
# (NC Carolina/NP-TL)
# (NC Iowa/NP)
# (NC Feb./NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Canada/NP)
# (NC Canada/NP)
# (NC Ben/NP Carson/NP)
# (NC Dwight/NP Eisenhower/NP)
# (NC Dwight/NP Eisenhower/NP)
# (NC Kate/NP)
# (NC San/NP Francisco/NP)
# (NC Chicago/NP)
# (NC Chicago/NP)
# (NC Texas/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Israel/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Nevada/NP)
# (NC Mexico/NP-TL)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Congress/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC Iowa/NP)
# (NC America/NP)
# (NC Americans/NPS)
# (NC Americans/NPS)
# (NC Fortune/NP)
# (NC Republicans/NPS)
# (NC Democrats/NPS)
# (NC Hillary/NP)
# (NC Bush/NP)
# (NC Korea/NP)
# (NC Germany/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Saudi/NP Arabia/NP)
# (NC Florida/NP)
# (NC Republicans/NPS)
# (NC Charlie/NP Rose/NP)
# (NC Scott/NP)
# (NC Scott/NP)
# (NC York/NP-TL)
# (NC Florida/NP)
# (NC Jersey/NP-TL)
# (NC Texas/NP)
# (NC Ireland/NP)
# (NC England/NP)
# (NC Spain/NP)
# (NC Carson/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP-TL)
# (NC Brazil/NP)
# (NC Mr./NP Jones/NP)
# (NC England/NP)
# (NC Ford/NP)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Tennessee/NP)
# (NC Tennessee/NP)
# (NC Mexico/NP)
# (NC Chicago/NP)
# (NC Michigan/NP)
# (NC Hampshire/NP-TL)
# (NC Iowa/NP)
# (NC Carolina/NP-TL)
# (NC Joe/NP)
# (NC America/NP)
# (NC Joe/NP)
# (NC Joe/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Kerry/NP-TL)
# (NC Hillary/NP)
# (NC Kerry/NP-TL)
# (NC Chicago/NP)
# (NC York/NP-TL)
# (NC Mexico/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Mexico/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC Carl/NP)
# (NC Mobile/NP)
# (NC Alabama/NP)
# (NC America/NP)
# (NC Dallas/NP)
# (NC Democrats/NPS)
# (NC Democrats/NPS)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Republicans/NPS)
# (NC Chris/NP)
# (NC Spanish/NP)
# (NC America/NP-TL)
# (NC Mexico/NP)
# (NC Harvard/NP)
# (NC Yale/NP-TL)
# (NC Princeton/NP)
# (NC Stanford/NP-TL)
# (NC Congress/NP)
# (NC Tom/NP)
# (NC Tom/NP)
# (NC Tom/NP)
# (NC Tom/NP)
# (NC Europe/NP)
# (NC Ray/NP)
# (NC Hillary/NP)
# (NC Iran/NP)
# (NC John/NP Kerry/NP-TL)
# (NC Israel/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Jeb/NP Bush/NP)
# (NC Graham/NP)
# (NC Perry/NP)
# (NC Paul/NP)
# (NC Paul/NP)
# (NC Jeb/NP Bush/NP)
# (NC Jeb/NP)
# (NC Hillary/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Paul/NP)
# (NC Joe/NP)
# (NC Hillary/NP)
# (NC Jeb/NP)
# (NC Jeb/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC Los/NP Angeles/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC America/NP)
# (NC Nashville/NP)
# (NC Nashville/NP)
# (NC Nashville/NP)
# (NC Nashville/NP)
# (NC Tennessee/NP)
# (NC Teller/NP)
# (NC Brooklyn/NP)
# (NC Queens/NP)
# (NC Manhattan/NP)
# (NC Manhattan/NP)
# (NC God/NP)
# (NC Nashville/NP)
# (NC Tennessee/NP)
# (NC Nashville/NP)
# (NC Teller/NP)
# (NC Nashville/NP)
# (NC Nashville/NP)
# (NC Tennessee/NP)
# (NC Fox/NP)
# (NC Nashville/NP)
# (NC Nashville/NP)
# (NC Fox/NP)
# (NC Republican/NP)
# (NC Republicans/NPS)
# (NC Washington/NP)
# (NC Washington/NP)
# (NC Washington/NP)
# (NC Mexico/NP-TL)
# (NC Mexico/NP-TL)
# (NC Tennessee/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Alabama/NP)
# (NC God/NP)
# (NC Alabama/NP)
# (NC Alabama/NP)
# (NC Iowa/NP)
# (NC Hampshire/NP-TL)
# (NC Hampshire/NP-TL)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Florida/NP)
# (NC Carolina/NP-TL)
# (NC Carolina/NP-TL)
# (NC Carolina/NP-TL)
# (NC Carolina/NP-TL)
# (NC York/NP-TL)
# (NC York/NP-TL)
# (NC York/NP-TL)
# (NC York/NP-TL)
# (NC York/NP-TL)
# (NC York/NP-TL)
# (NC Nevada/NP)
# (NC Carolina/NP-TL)
# (NC Jeb/NP Bush/NP)
# (NC Patrick/NP)
# (NC Murray/NP)
# (NC Democrat/NP)
# (NC Bible/NP)
# (NC Iowa/NP)
# (NC Bible/NP)
# (NC Steve/NP)
# (NC Donald/NP)
# (NC Steve/NP)
# (NC Mark/NP)
# (NC Mark/NP)
# (NC Mark/NP)
# (NC Mark/NP)
# (NC Mark/NP)
# (NC Bill/NP)
# (NC Harry/NP Truman/NP)
# (NC Truman/NP)
# (NC Donald/NP)
# (NC Ellen/NP)
# (NC California/NP)
# (NC Boeing/NP)
# (NC Ellen/NP)
# (NC California/NP)
# (NC Manhattan/NP)
# (NC Washington/NP)
# (NC Pennsylvania/NP)
# (NC Pennsylvania/NP-TL)
# (NC Congress/NP)
# (NC Carl/NP)
# (NC Carl/NP)
# (NC Carl/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Los/NP Angeles/NP)
# (NC Japan/NP)
# (NC Japan/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC America/NP-TL)
# (NC San/NP Francisco/NP)
# (NC Forbes/NP)
# (NC Forbes/NP)
# (NC Scotland/NP)
# (NC Massachusetts/NP)
# (NC Nashville/NP)
# (NC Ernie/NP)
# (NC Ernie/NP)
# (NC Georgia/NP)
# (NC Georgia/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Alabama/NP)
# (NC Iowa/NP)
# (NC Iowa/NP)
# (NC Democrats/NPS)
# (NC Jeb/NP Bush/NP)
# (NC Hillary/NP)
# (NC Bush/NP)
# (NC Jeb/NP)
# (NC Jeb/NP Bush/NP)
# (NC Jeb/NP)
# (NC Jeb/NP)
# (NC Asians/NPS)
# (NC York/NP-TL)
# (NC Asians/NPS)
# (NC Asians/NPS)
# (NC Asians/NPS)
# (NC Asians/NPS)
# (NC Jose/NP)
# (NC Jose/NP)
# (NC Donald/NP)
# (NC York/NP-TL)
# (NC York/NP-TL)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC China/NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Hillary/NP)
# (NC Kate/NP)
# (NC San/NP Francisco/NP)
# (NC Massachusetts/NP)
# (NC California/NP)
# (NC Baltimore/NP)
# (NC Chicago/NP)
# (NC Baltimore/NP)
# (NC Chicago/NP)
# (NC Ferguson/NP)
# (NC St./NP Louis/NP)
# (NC Baltimore/NP)
# (NC Chicago/NP)
# (NC York/NP-TL)
# (NC Germany/NP)
# (NC Germany/NP)
# (NC Russia/NP)
# (NC Iran/NP)
# (NC Russia/NP)
# (NC Iran/NP)
# (NC Iran/NP)
# (NC Russia/NP)
# (NC York/NP-TL)
# (NC John/NP)
# (NC John/NP)
# (NC Black/NP)
# (NC Black/NP)
# (NC Mr./NP)
# (NC China/NP)
# (NC China/NP)
# (NC Japan/NP)
# (NC Sharon/NP)
# (NC Sharon/NP)
# (NC Sharon/NP)
# (NC Sharon/NP)
# (NC Sharon/NP)
# (NC Sharon/NP)
# (NC John/NP)
# (NC Donald/NP)
# (NC John/NP)
# (NC Carl/NP)
# (NC Chris/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Iran/NP)
# (NC Iraq/NP)
# (NC Iraq/NP)
# (NC Bush/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC France/NP)
# (NC France/NP)
# (NC Turkey/NP)
# (NC Turkey/NP)
# (NC Iraq/NP)
# (NC Syria/NP)
# (NC Iran/NP)
# (NC Turkey/NP)
# (NC Americans/NPS)
# (NC Indiana/NP)
# (NC Mike/NP)
# (NC Indiana/NP)
# (NC Indiana/NP)
# (NC Congress/NP)
# (NC Republican/NP)
# (NC Indiana/NP)
# (NC Mike/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC November/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Mike/NP)
# (NC Mike/NP)
# (NC Islam/NP)
# (NC San/NP)
# (NC Orlando/NP-HL)
# (NC Paris/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Donald/NP)
# (NC Iraq/NP)
# (NC Scotland/NP)
# (NC Donald/NP)
# (NC Mike/NP)
# (NC Mike/NP)
# (NC Richard/NP Nixon/NP)
# (NC Dwight/NP D./NP Eisenhower/NP)
# (NC Cleveland/NP)
# (NC Johnson/NP)
# (NC Johnson/NP)
# (NC Lyndon/NP Johnson/NP)
# (NC Johnson/NP)
# (NC Johnson/NP)
# (NC Christians/NPS)
# (NC Jews/NPS)
# (NC Mr./NP)
# (NC Lyndon/NP Johnson/NP)
# (NC Texas/NP)
# (NC Mike/NP)
# (NC Mike/NP)
# (NC Indiana/NP)
# (NC Indiana/NP)
# (NC Indiana/NP)
# (NC York/NP-TL)
# (NC Pennsylvania/NP)
# (NC Indiana/NP)
# (NC Indiana/NP)
# (NC York/NP-TL)
# (NC Bill/NP)
# (NC Bill/NP)
# (NC Mexico/NP-TL)
# (NC Donald/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Mexico/NP)
# (NC Ford/NP)
# (NC Michigan/NP)
# (NC Michigan/NP)
# (NC Michigan/NP)
# (NC Mike/NP)
# (NC Indiana/NP)
# (NC Mike/NP)
# (NC Karen/NP)
# (NC Indiana/NP)
# (NC Indiana/NP)
# (NC May/NP)
# (NC January/NP)
# (NC Indiana/NP)
# (NC Indiana/NP)
# (NC Indiana/NP)
# (NC Midwest/NP)
# (NC Mike/NP)
# (NC Indiana/NP-TL)
# (NC Bobby/NP)
# (NC Bobby/NP)
# (NC Indiana/NP)
# (NC Bobby/NP)
# (NC Indiana/NP)
# (NC Hillary/NP)
# (NC Arizona/NP)
# (NC Hillary/NP)
# (NC Mike/NP)
# (NC Indianapolis/NP)
# (NC Mike/NP)
# (NC Indiana/NP)
# (NC Indiana/NP)
# (NC America/NP)
# (NC Indiana/NP)
# (NC Donald/NP)
# (NC Pennsylvania/NP)
# (NC Eric/NP)
# (NC Don/NP)
# (NC Indiana/NP)
# (NC Indiana/NP)
# (NC Mike/NP)
# (NC Indiana/NP)
# (NC Ted/NP)
# (NC Ted/NP Cruz/NP)
# (NC Ted/NP)
# (NC Mike/NP)
# (NC T./NP)
# (NC America/NP)
# (NC Steel/NP)
# (NC Pittsburgh/NP)
# (NC Pennsylvania/NP)
# (NC Mexico/NP)
# (NC Pennsylvania/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC Donald/NP)
# (NC U.S./NP)
# (NC Donald/NP)
# (NC America/NP)
# (NC Britain/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC America/NP)
# (NC George/NP Washington/NP)
# (NC Alexander/NP Hamilton/NP)
# (NC Republican/NP)
# (NC Abraham/NP Lincoln/NP)
# (NC America/NP)
# (NC Bill/NP)
# (NC Hillary/NP)
# (NC Bill/NP)
# (NC Hillary/NP)
# (NC Bill/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC China/NP)
# (NC Pittsburgh/NP)
# (NC Pennsylvania/NP-TL)
# (NC China/NP)
# (NC America/NP)
# (NC China/NP)
# (NC Hillary/NP)
# (NC Korea/NP-TL)
# (NC May/NP)
# (NC Korea/NP-TL)
# (NC American/NP)
# (NC Hillary/NP)
# (NC Americans/NPS)
# (NC America/NP)
# (NC U.S./NP)
# (NC China/NP)
# (NC Mexico/NP-TL)
# (NC Vietnam/NP-TL)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC China/NP)
# (NC U.S./NP)
# (NC China/NP)
# (NC China/NP)
# (NC U.S./NP)
# (NC Hillary/NP)
# (NC Hillary/NP)
# (NC China/NP)
# (NC Korea/NP-TL)
# (NC America/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC Pennsylvania/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Hillary/NP)
# (NC America/NP)
# (NC America/NP)
# (NC Americans/NPS)
# (NC America/NP)

# %%
proper_noun_list = []
for tree in mychunks:
    for subtree in tree.subtrees():
        if subtree.label() == 'NC': 
            proper_noun_list.append(subtree.leaves())

# %%
updated_proper_noun_list = []
temp_list = []
for item in proper_noun_list:
    if (len(item) > 1):
        for list in item:
            temp_list.append(list[0])
        new_proper_noun = ' '.join(temp_list)
        temp_list = []
        updated_proper_noun_list.append(new_proper_noun)
    else:
        updated_proper_noun_list.append(item[0][0])

# %%
fdist = nltk.FreqDist(updated_proper_noun_list)
fdist.most_common(20)
# Out:
# [('China', 194),
#  ('America', 175),
#  ('Mexico', 150),
#  ('Hillary', 145),
#  ('Iowa', 115),
#  ('Iran', 82),
#  ('Israel', 80),
#  ('Iraq', 68),
#  ('Japan', 63),
#  ('Florida', 52),
#  ('Donald', 51),
#  ('Hampshire', 44),
#  ('Americans', 43),
#  ('Carolina', 40),
#  ('York', 40),
#  ('Mr.', 36),
#  ('Democrats', 35),
#  ('Cruz', 35),
#  ('Republicans', 35),
#  ('Korea', 34)]
